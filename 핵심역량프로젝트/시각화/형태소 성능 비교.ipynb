# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

font_location = 'C:/Windows/Fonts/malgun.ttf'
font_name = fm.FontProperties(fname = font_location).get_name()
matplotlib.rc('font',family = font_name)

# 주어진 점수 데이터
scores_text_morphed = {
    "extra_trees": 0.8536585365853658,
    "ridge_classifier": 0.9024390243902439,
    "logistic_regression": 0.8926829268292683,
    "naive_bayes": 0.8,
    "svm": 0.9121951219512195,
    "hard_model": 0.9024390243902439,
    "soft_model": 0.8585365853658536
}

# 가상의 text_essential_morphed 데이터 (실제 점수로 교체 필요)
scores_text_essential_morphed = {
    "extra_trees": 0.850,  # 예시 점수, 실제 점수로 교체
    "ridge_classifier": 0.900,  # 예시 점수, 실제 점수로 교체
    "logistic_regression": 0.890,  # 예시 점수, 실제 점수로 교체
    "naive_bayes": 0.790,  # 예시 점수, 실제 점수로 교체
    "svm": 0.910,  # 예시 점수, 실제 점수로 교체
    "hard_model": 0.900,  # 예시 점수, 실제 점수로 교체
    "soft_model": 0.855  # 예시 점수, 실제 점수로 교체
}

# 모델 이름 리스트
models = list(scores_text_morphed.keys())

# 각 모델에 대한 점수 리스트
text_morphed_scores = [scores_text_morphed[model] for model in models]
text_essential_morphed_scores = [scores_text_essential_morphed[model] for model in models]

# 막대 너비와 인덱스를 설정합니다.
bar_width = 0.35
index = np.arange(len(models))

# 그래프 크기 설정
fig, ax = plt.subplots(figsize=(12, 8))  # 크기를 12x8 인치로 설정

# 막대 그래프를 그립니다.
bar1 = ax.bar(index, text_morphed_scores, bar_width, label='전체 형태소')
bar2 = ax.bar(index + bar_width, text_essential_morphed_scores, bar_width, label='필수 형태소')

# 레이블과 제목을 설정합니다.
ax.set_xlabel('Models', fontsize=14)
ax.set_ylabel('Test Scores', fontsize=14)
ax.set_title('전체 형태소 - 필수 형태소', fontsize=16)
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(models, fontsize=12, rotation=45)
ax.legend(fontsize=12)
ax.tick_params(axis='y', labelsize=14)
ax.tick_params(axis='x', labelsize=14)
# y축 범위를 0부터 1까지로 설정
ax.set_ylim(0, 1)

# 각 막대 위에 수치를 추가합니다.
for bar in bar1:
    height = bar.get_height()
    ax.annotate(f'{height:.3f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points", ha='center', va='bottom', fontsize=10)

for bar in bar2:
    height = bar.get_height()
    ax.annotate(f'{height:.3f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points", ha='center', va='bottom', fontsize=10)

# 그래프를 보여줍니다.
plt.tight_layout()  # 레이아웃 조정
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 데이터 정의
scores_text_morphed = {
    "extra_trees": 0.8536585365853658,
    "ridge_classifier": 0.9024390243902439,
    "logistic_regression": 0.8926829268292683,
    "naive_bayes": 0.8,
    "svm": 0.9121951219512195,
    "hard_model": 0.9024390243902439,
    "soft_model": 0.8585365853658536
}

scores_text_eomi_giho_essential_morphed = {
    "extra_trees": 0.8439024390243902,
    "ridge_classifier": 0.8780487804878049,
    "logistic_regression": 0.8926829268292683,
    "naive_bayes": 0.8292682926829268,
    "svm": 0.8731707317073171,
    "hard_model": 0.8829268292682927,
    "soft_model": 0.8731707317073171
}

# 모델 이름 리스트
models = list(scores_text_morphed.keys())

# 점수 리스트
text_morphed_scores = [scores_text_morphed[model] for model in models]
text_eomi_giho_essential_morphed_scores = [scores_text_eomi_giho_essential_morphed[model] for model in models]

# 막대 너비와 인덱스 설정
bar_width = 0.35
index = np.arange(len(models))

# 그래프 크기 설정
fig, ax = plt.subplots(figsize=(12, 8))  # 크기를 12x8 인치로 설정

# 막대 그래프를 그립니다
bar1 = ax.bar(index, text_morphed_scores, bar_width, label='전체 형태소')
bar2 = ax.bar(index + bar_width, text_eomi_giho_essential_morphed_scores, bar_width, label='필수 형태소 어미 포함')

# 레이블과 제목을 설정합니다
ax.set_xlabel('Models', fontsize=14)
ax.set_ylabel('Test Scores', fontsize=14)
ax.set_title('전체 형태소 - 필수 형태소 어미 포함', fontsize=16)
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(models, fontsize=12, rotation=45)
ax.legend(fontsize=12)
ax.tick_params(axis='y', labelsize=14)
ax.tick_params(axis='x', labelsize=14)
# y축 범위를 0부터 1까지로 설정
ax.set_ylim(0, 1)

# 각 막대 위에 수치를 추가합니다
for bar in bar1:
    height = bar.get_height()
    ax.annotate(f'{height:.3f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 포인트 수직 오프셋
                textcoords="offset points", ha='center', va='bottom', fontsize=10)

for bar in bar2:
    height = bar.get_height()
    ax.annotate(f'{height:.3f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 포인트 수직 오프셋
                textcoords="offset points", ha='center', va='bottom', fontsize=10)

# 그래프를 보여줍니다
plt.tight_layout()  # 레이아웃 조정
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ax.tick_params(axis='y', labelsize=14)
ax.tick_params(axis='x', labelsize=14)
# 데이터 준비
models = [
    'extra_trees', 
    'ridge_classifier', 
    'logistic_regression', 
    'naive_bayes', 
    'svm', 
    'hard_model', 
    'soft_model'
]
countvec_scores = [
    0.8146341463414634, 
    0.8, 
    0.8731707317073171, 
    0.848780487804878, 
    0.8146341463414634, 
    0.8536585365853658, 
    0.8731707317073171
]
tfidf_scores = [
    0.8536585365853658, 
    0.9024390243902439, 
    0.8926829268292683, 
    0.8, 
    0.9121951219512195, 
    0.8975609756097561, 
    0.8536585365853658
]

# 시각화

plt.figure(figsize=(14, 8))
bar_width = 0.35
index = np.arange(len(models))

# 바 차트
plt.bar(index, countvec_scores, bar_width, label='CountVec 점수', alpha=0.7, color='b')
plt.bar(index + bar_width, tfidf_scores, bar_width, label='TFIDF 점수', alpha=0.7, color='r')
plt.tick_params(axis='y', labelsize=14)
plt.tick_params(axis='x', labelsize=14)
# 레이블 및 제목 설정
plt.xlabel('모델', fontsize=14)
plt.ylabel('테스트 점수', fontsize=14)
plt.title("CountVec - TFIDF 성능 비교", fontsize=16)
plt.xticks(index + bar_width / 2, models, fontsize=12, rotation=45)
plt.legend(fontsize=12)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 딕셔너리 데이터
score_dict = {
    "models": [
        "extra_trees",
        "ridge_classifier",
        "logistic_regression",
        "naive_bayes",
        "svm",
        "hard_model",
        "soft_model"
    ],
    "text_morphed_scores": [
        0.8737373737373737,
        0.8787878787878788,
        0.8737373737373737,
        0.8131313131313131,
        0.8737373737373737,
        0.8838383838383839,
        0.8585858585858586
    ],
    "text_essential_morphed_scores": [
        0.8535353535353535,
        0.8636363636363636,
        0.8383838383838383,
        0.8333333333333334,
        0.8333333333333334,
        0.8535353535353535,
        0.8434343434343434
    ]
}

# 모델 이름 리스트
models = score_dict['models']

# 점수 리스트
text_morphed_scores = score_dict['text_morphed_scores']
text_essential_morphed_scores = score_dict['text_essential_morphed_scores']

# 막대 너비와 인덱스 설정
bar_width = 0.35
index = np.arange(len(models))

# 그래프 크기 설정
fig, ax = plt.subplots(figsize=(12, 8))  # 크기를 12x8 인치로 설정

# 막대 그래프를 그립니다
bar1 = ax.bar(index, text_morphed_scores, bar_width, label='전체 형태소')
bar2 = ax.bar(index + bar_width, text_essential_morphed_scores, bar_width, label='필수 형태소')

# 레이블과 제목을 설정합니다
ax.set_xlabel('Models', fontsize=14)
ax.set_ylabel('Test Scores', fontsize=14)
ax.set_title('전체 형태소 - 필수 형태소 어미 포함', fontsize=16)
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(models, fontsize=12, rotation=45)
ax.legend(fontsize=12)
ax.tick_params(axis='y', labelsize=14)
ax.tick_params(axis='x', labelsize=14)
# y축 범위를 0.6부터 1까지로 설정
ax.set_ylim(0.6, 1)

# 각 막대 위에 수치를 추가합니다
for bar in bar1:
    height = bar.get_height()
    ax.annotate(f'{height:.3f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 포인트 수직 오프셋
                textcoords="offset points", ha='center', va='bottom', fontsize=10)

for bar in bar2:
    height = bar.get_height()
    ax.annotate(f'{height:.3f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 포인트 수직 오프셋
                textcoords="offset points", ha='center', va='bottom', fontsize=10)

# 그래프를 보여줍니다
plt.tight_layout()  # 레이아웃 조정
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 점수 데이터를 딕셔너리로 정의
score_dict = {
    "models": [
        "extra_trees",
        "ridge_classifier",
        "logistic_regression",
        "naive_bayes",
        "svm",
        "hard_model",
        "soft_model"
    ],
    "text_morphed_scores": [
        0.8737373737373737,
        0.8787878787878788,
        0.8737373737373737,
        0.8131313131313131,
        0.8737373737373737,
        0.8838383838383839,
        0.8585858585858586
    ],
    "text_essential_morphed_scores": [
        0.8535353535353535,
        0.8636363636363636,
        0.8383838383838383,
        0.8333333333333334,
        0.8333333333333334,
        0.8535353535353535,
        0.8434343434343434
    ],
    "text_eomi_giho_essential_morphed_scores": [
        0.8636363636363636,
        0.8838383838383839,
        0.8838383838383839,
        0.8333333333333334,
        0.8636363636363636,
        0.8838383838383839,
        0.8737373737373737
    ]
}

# 모델 이름 리스트
models = score_dict['models']

# 점수 리스트
text_morphed_scores = score_dict['text_morphed_scores']
text_essential_morphed_scores = score_dict['text_essential_morphed_scores']
text_eomi_giho_essential_morphed_scores = score_dict['text_eomi_giho_essential_morphed_scores']

# 막대 너비와 인덱스 설정
bar_width = 0.25
index = np.arange(len(models))

# 그래프 크기 설정
fig, ax = plt.subplots(figsize=(14, 8))  # 크기를 14x8 인치로 설정

# 막대 그래프를 그립니다
bar1 = ax.bar(index, text_morphed_scores, bar_width, label='전체 형태소')
bar2 = ax.bar(index + bar_width, text_essential_morphed_scores, bar_width, label='필수 형태소')
bar3 = ax.bar(index + 2 * bar_width, text_eomi_giho_essential_morphed_scores, bar_width, label='필수 형태소 어미 포함')

# 레이블과 제목을 설정합니다
ax.set_xlabel('Models', fontsize=14)
ax.set_ylabel('Test Scores', fontsize=14)
ax.set_title('형태소 분석 케이스별 모델 성능 비교', fontsize=16)
ax.set_xticks(index + bar_width)
ax.set_xticklabels(models, fontsize=12, rotation=45)
ax.legend(fontsize=12)
ax.tick_params(axis='y', labelsize=14)
ax.tick_params(axis='x', labelsize=14)
# y축 범위를 0.6부터 1까지로 설정
ax.set_ylim(0.6, 1)

# 각 막대 위에 수치를 추가합니다
for bar in bar1:
    height = bar.get_height()
    ax.annotate(f'{height:.3f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 포인트 수직 오프셋
                textcoords="offset points", ha='center', va='bottom', fontsize=10)

for bar in bar2:
    height = bar.get_height()
    ax.annotate(f'{height:.3f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 포인트 수직 오프셋
                textcoords="offset points", ha='center', va='bottom', fontsize=10)

for bar in bar3:
    height = bar.get_height()
    ax.annotate(f'{height:.3f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 포인트 수직 오프셋
                textcoords="offset points", ha='center', va='bottom', fontsize=10)

# 그래프를 보여줍니다
plt.tight_layout()  # 레이아웃 조정
plt.show()

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

font_location = 'C:/Windows/Fonts/malgun.ttf'
font_name = fm.FontProperties(fname = font_location).get_name()
matplotlib.rc('font',family = font_name)

# JSON 데이터를 로드
json_data = """
{
    "scores": {
        "text_essential_morphed": {
            "extra_trees": {
                "test_score": 0.8439024390243902,
                "cv_mean_score": 0.8302708364506957
            },
            "ridge_classifier": {
                "test_score": 0.8731707317073171,
                "cv_mean_score": 0.8669235373335329
            },
            "logistic_regression": {
                "test_score": 0.8536585365853658,
                "cv_mean_score": 0.8571449947628311
            },
            "naive_bayes": {
                "test_score": 0.8195121951219512,
                "cv_mean_score": 0.8217043244052074
            },
            "svm": {
                "test_score": 0.8585365853658536,
                "cv_mean_score": 0.8571674397725573
            },
            "hard_model": {
                "test_score": 0.8585365853658536,
                "cv_mean_score": 0.8656965434685022
            },
            "soft_model": {
                "test_score": 0.8536585365853658,
                "cv_mean_score": 0.8669085739937155
            }
        },
        "text_eomi_giho_essential_morphed": {
            "extra_trees": {
                "test_score": 0.8439024390243902,
                "cv_mean_score": 0.8693475983839593
            },
            "ridge_classifier": {
                "test_score": 0.8780487804878049,
                "cv_mean_score": 0.865674098458776
            },
            "logistic_regression": {
                "test_score": 0.8926829268292683,
                "cv_mean_score": 0.8717866227742033
            },
            "naive_bayes": {
                "test_score": 0.8292682926829268,
                "cv_mean_score": 0.8204997755499027
            },
            "svm": {
                "test_score": 0.8731707317073171,
                "cv_mean_score": 0.8607885680083796
            },
            "hard_model": {
                "test_score": 0.8829268292682927,
                "cv_mean_score": 0.8766497082148735
            },
            "soft_model": {
                "test_score": 0.8731707317073171,
                "cv_mean_score": 0.8791036959449349
            }
        }
    }
}
"""

data = json.loads(json_data)

models = list(data['scores']['text_essential_morphed'].keys())
essential_test_scores = [data['scores']['text_essential_morphed'][model]['test_score'] for model in models]
eomi_giho_test_scores = [data['scores']['text_eomi_giho_essential_morphed'][model]['test_score'] for model in models]

x = np.arange(len(models))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(14, 7))
rects1 = ax.bar(x - width/2, essential_test_scores, width, label='필수 형태소')
rects2 = ax.bar(x + width/2, eomi_giho_test_scores, width, label='필수 형태소 어미 포함')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Test Scores')
ax.set_title('필수 형태소 - 필수 형태소 어미 포함')
ax.set_xticks(x)
ax.set_xticklabels(models, rotation=45, ha='right')
ax.legend()
ax.tick_params(axis='y', labelsize=14)
ax.tick_params(axis='x', labelsize=14)
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# JSON 데이터를 직접 코드에 포함
data = {
    "scores": {
        "text_morphed_masked": {
            "extra_trees": {
                "test_score": 0.8634146341463415,
                "cv_mean_score": 0.8351039952117313
            },
            "ridge_classifier": {
                "test_score": 0.8634146341463415,
                "cv_mean_score": 0.8669010923238067
            },
            "logistic_regression": {
                "test_score": 0.8731707317073171,
                "cv_mean_score": 0.8522445009726172
            },
            "naive_bayes": {
                "test_score": 0.7902439024390244,
                "cv_mean_score": 0.77655244650606
            },
            "svm": {
                "test_score": 0.8878048780487805,
                "cv_mean_score": 0.8571300314230136
            },
            "hard_model": {
                "test_score": 0.8634146341463415,
                "cv_mean_score": 0.8607810863384706
            },
            "soft_model": {
                "test_score": 0.848780487804878,
                "cv_mean_score": 0.8571300314230136
            }
        },
        "text_essential_morphed_masked": {
            "extra_trees": {
                "test_score": 0.8390243902439024,
                "cv_mean_score": 0.8424809217417326
            },
            "ridge_classifier": {
                "test_score": 0.848780487804878,
                "cv_mean_score": 0.8461693850067336
            },
            "logistic_regression": {
                "test_score": 0.824390243902439,
                "cv_mean_score": 0.8376178363010623
            },
            "naive_bayes": {
                "test_score": 0.8146341463414634,
                "cv_mean_score": 0.8082971719287745
            },
            "svm": {
                "test_score": 0.8341463414634146,
                "cv_mean_score": 0.8437228789465809
            },
            "hard_model": {
                "test_score": 0.8439024390243902,
                "cv_mean_score": 0.8473888972018555
            },
            "soft_model": {
                "test_score": 0.848780487804878,
                "cv_mean_score": 0.8522519826425258
            }
        },
        "text_eomi_giho_essential_morphed_masked": {
            "extra_trees": {
                "test_score": 0.8439024390243902,
                "cv_mean_score": 0.8510474337872214
            },
            "ridge_classifier": {
                "test_score": 0.8585365853658536,
                "cv_mean_score": 0.8534864581774653
            },
            "logistic_regression": {
                "test_score": 0.8634146341463415,
                "cv_mean_score": 0.8583645069579531
            },
            "naive_bayes": {
                "test_score": 0.824390243902439,
                "cv_mean_score": 0.8058656292084393
            },
            "svm": {
                "test_score": 0.8536585365853658,
                "cv_mean_score": 0.8571375130929223
            },
            "hard_model": {
                "test_score": 0.8634146341463415,
                "cv_mean_score": 0.8632575190782582
            },
            "soft_model": {
                "test_score": 0.8585365853658536,
                "cv_mean_score": 0.8669010923238067
            }
        }
    }
}

# 모델 성능 추출
def extract_scores(data, text_type):
    models = list(data['scores'][text_type].keys())
    test_scores = [data['scores'][text_type][model]['test_score'] for model in models]
    cv_mean_scores = [data['scores'][text_type][model]['cv_mean_score'] for model in models]
    return models, test_scores, cv_mean_scores

models, test_scores_masked, cv_mean_scores_masked = extract_scores(data, 'text_morphed_masked')
_, test_scores_essential_masked, cv_mean_scores_essential_masked = extract_scores(data, 'text_essential_morphed_masked')
_, test_scores_eomi_giho_masked, cv_mean_scores_eomi_giho_masked = extract_scores(data, 'text_eomi_giho_essential_morphed_masked')

x = np.arange(len(models))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots(figsize=(18, 9))

rects1 = ax.bar(x - width, test_scores_masked, width, label='전체 형태소 마스킹')
rects2 = ax.bar(x, test_scores_essential_masked, width, label='필수 형태소 마스킹')
rects3 = ax.bar(x + width, test_scores_eomi_giho_masked, width, label='어미 포함 필수 형태소 마스킹')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Test Scores')
ax.set_title('전체 형태소 마스킹 - 필수 형태소 마스킹 - 어미 포함 필수 형태소 마스킹')
ax.set_xticks(x)
ax.set_xticklabels(models, rotation=45, ha='right')
ax.legend()
ax.tick_params(axis='y', labelsize=14)
ax.tick_params(axis='x', labelsize=14)
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)

fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# JSON 데이터를 직접 코드에 포함
data = {
    "cases_best_scores": {
        "전체 형태소": {
            "model_name": "svm",
            "test_score": 0.9121951219512195
        },
        "필수 형태소": {
            "model_name": "ridge_classifier",
            "test_score": 0.8731707317073171
        },
        "필수 형태소 명사 제거": {
            "model_name": "hard_model",
            "test_score": 0.8048780487804879
        },
        "어미 포함 필수 형태소": {
            "model_name": "logistic_regression",
            "test_score": 0.8926829268292683
        },
        "어미 포함 필수 형태소 명사 제거": {
            "model_name": "soft_model",
            "test_score": 0.8292682926829268
        },
        "전체 형태소 마스킹": {
            "model_name": "svm",
            "test_score": 0.8878048780487805
        },
        "필수 형태소 마스킹": {
            "model_name": "ridge_classifier",
            "test_score": 0.848780487804878
        },
        "필수 형태소 명사 제거 마스킹": {
            "model_name": "hard_model",
            "test_score": 0.8097560975609757
        },
        "어미 포함 필수 형태소 마스킹": {
            "model_name": "logistic_regression",
            "test_score": 0.8634146341463415
        },
        "어미 포함 필수 형태소 명사 제거 마스킹": {
            "model_name": "soft_model",
            "test_score": 0.8292682926829268
        }
    }
}

# 형태소 분석 방법 이름
morpheme_types = list(data["cases_best_scores"].keys())
best_test_scores = [data["cases_best_scores"][morpheme]["test_score"] for morpheme in morpheme_types]

x = np.arange(len(morpheme_types))  # the label locations
width = 0.6  # the width of the bars

fig, ax = plt.subplots(figsize=(12, 7))

rects = ax.bar(x, best_test_scores, width, label='Test Score', color='r', alpha=0.7)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Test Scores', fontsize=14)
ax.set_title('aggr 컬럼 형태소 분석별 성능 비교', fontsize=16)
ax.set_xticks(x)
ax.set_xticklabels(morpheme_types, rotation=45, ha='right', fontsize=12)
ax.legend()

# y축 상한선을 조정하여 숫자가 그래프를 벗어나지 않게 설정
ax.set_ylim(0, 1.1)

# y축 수치 글자 크기 설정
ax.tick_params(axis='y', labelsize=14)

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=12)

autolabel(rects)

fig.tight_layout()

plt.show()
