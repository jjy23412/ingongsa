# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.pipeline import Pipeline
from sklearn.ensemble import VotingClassifier
import joblib

# 데이터 불러오기
os.chdir('C:/Users/USER/Desktop/핵심역량 프로젝트/데이터/라벨링 데이터')

data = pd.read_csv('0727_masking_labeling_data.csv')

data.columns
# Out:
# Index(['Unnamed: 0', 'number', 'title', 'title_morphed',
#        'title_essential_morphed', 'title_removeNN_essential_morphed',
#        'title_eomi_giho_essential_morphed',
#        'title_eomi_giho_essential_removeNN_morphed', 'title_morphed_masked',
#        'title_essential_morphed_masked',
#        'title_removeNN_essential_morphed_masked',
#        'title_eomi_giho_essential_morphed_masked',
#        'title_eomi_giho_essential_removeNN_morphed_masked', 'name', 'date',
#        'answer_state', 'contents', 'text_morphed', 'text_essential_morphed',
#        'text_removeNN_essential_morphed', 'text_eomi_giho_essential_morphed',
#        'text_eomi_giho_essential_removeNN_morphed', 'text_morphed_masked',
#        'text_essential_morphed_masked',
#        'text_removeNN_essential_morphed_masked',
#        'text_eomi_giho_essential_morphed_masked',
#        'text_eomi_giho_essential_removeNN_morphed_masked', 'has_attachment',
#        'answer_contents', 'registration_number', 'charge_name', 'charge',
#        'answer_date', 'title_and_contents', 'aggr', '욕설_모욕', '비꼼_시비', '성희롱',
#        '요지불명', '저격성 민원', '완전중복', '반복', '출처'],
#       dtype='object')

# %%
len(data[data.aggr == 0])
# Out:
# 6990

# %%
titles = data.columns[3:13]
texts = data.columns[17:27]

# %% [markdown]
# ## TfidfVectorizer 마스킹 X, 파라미터 default - best

# %%
import json
import os
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import ExtraTreesClassifier, VotingClassifier
from sklearn.linear_model import RidgeClassifier, LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, cross_val_score
import joblib
import pandas as pd

# 모델 점수를 저장할 경로
model_scores_save_path = 'C:/Users/USER/Desktop/핵심역량 프로젝트/데이터/모델/scores/all_range_traing/'

# 'scores'와 'cases_best_scores' 키로 초기화된 딕셔너리
All_model_scores = {'scores': {}, 'cases_best_scores': {}}

target_columns = ['aggr', '욕설_모욕', '비꼼_시비', '반복', '요지불명', '저격성 민원']
best_title = ['title_eomi_giho_essential_morphed', 'title_morphed_masked', 'title_eomi_giho_essential_morphed', 'title_essential_morphed', 'title_morphed', 'title_eomi_giho_essential_morphed_masked']
best_text = ['text_eomi_giho_essential_morphed', 'text_morphed_masked', 'text_eomi_giho_essential_morphed', 'text_essential_morphed', 'text_morphed', 'text_eomi_giho_essential_morphed_masked']
best_model = ['LogisticRegression','RidgeClassifier','RidgeClassifier','hard_model','soft_model','SVC']

# 각 타겟 컬럼에 대해 모델 학습 및 평가
for title, text, target_column in zip(best_title, best_text, target_columns):

    print(f'{target_column} 학습 시작...\n')
    All_model_scores[target_column] = {'scores': {}, 'cases_best_scores': {}, 'range_test_scores': {}}
    
    # 데이터 설정
    selected_columns = [title, text, 'aggr', '욕설_모욕', '비꼼_시비', '반복', '요지불명', '저격성 민원']
    data1 = data[selected_columns][data[target_column] == 0]
    data2 = data[selected_columns][data[target_column] == 1]
    data1 = data1[300:300 + len(data2)]
    
    data3 = pd.concat([data1, data2])
    data_contents = data3[title] + ' ' + data3[text]
    data_labeling = data3[target_column]

    # 데이터 분할
    X_train, X_test, y_train, y_test = train_test_split(data_contents, data_labeling, stratify=data_labeling, test_size=0.2, random_state=42)

    pipelines = {
        'extra_trees': Pipeline([
            ('vect', TfidfVectorizer()),
            ('et', ExtraTreesClassifier())
        ]),
        'ridge_classifier': Pipeline([
            ('vect', TfidfVectorizer()),
            ('ridge', RidgeClassifier())
        ]),
        'logistic_regression': Pipeline([
            ('vect', TfidfVectorizer()),
            ('lr', LogisticRegression())
        ]),
        'naive_bayes': Pipeline([
            ('vect', TfidfVectorizer()),
            ('nb', MultinomialNB())
        ]),
        'svm': Pipeline([
            ('vect', TfidfVectorizer()),
            ('svm', SVC())
        ]),
        'hard_model': Pipeline([
            ('vect', TfidfVectorizer()),
            ('hard_model', VotingClassifier([('LR', LogisticRegression()), ('ridge', RidgeClassifier()), ('svm', SVC()), ('et', ExtraTreesClassifier()), ('nb', MultinomialNB())], voting='hard'))
        ]),
        'soft_model': Pipeline([
            ('vect', TfidfVectorizer()),
            ('soft_model', VotingClassifier([('LR', LogisticRegression()), ('svm', SVC(probability=True)), ('et', ExtraTreesClassifier()), ('nb', MultinomialNB())], voting='soft'))
        ])
    }

    case_model_scores = {}
    best_model_name = None
    best_test_score = 0
    best_cv_score = 0

    # 모델 훈련 및 평가
    for model_name, pipeline in pipelines.items():
        print(f"{model_name} 학습 중... (타겟: {target_column})")

        X_train_tfidf = pipeline.named_steps['vect'].fit_transform(X_train)
        X_test_tfidf = pipeline.named_steps['vect'].transform(X_test)

        print(f"{model_name} - X_train 크기: {X_train_tfidf.shape}")
        print(f"{model_name} - X_test 크기: {X_test_tfidf.shape}")

        pipeline.fit(X_train, y_train)

        cv_scores = cross_val_score(pipeline, X_train, y_train, cv=5, scoring='accuracy')

        train_score = pipeline.score(X_train, y_train)
        test_score = pipeline.score(X_test, y_test)
        print(f"{model_name} 학습 데이터 점수: {train_score:.4f}")
        print(f"{model_name} 테스트 데이터 점수: {test_score:.4f}")
        print(f"{model_name} 교차 검증 점수: {cv_scores}")
        print(f"{model_name} 교차 검증 평균 점수: {cv_scores.mean():.4f}\n")

        model_save_path = os.path.join('C:/Users/USER/Desktop/핵심역량 프로젝트/데이터/모델/', f'{text}_{model_name}_tfidf_model.pkl')
        joblib.dump(pipeline, model_save_path)
        case_model_scores[model_name] = {
            'test_score': test_score,
            'cv_mean_score': cv_scores.mean(),
            'data_range': f'300~{300 + len(data2)}'  # 데이터 범위 추가
        }

        # 최고 점수 갱신
        if test_score > best_test_score:
            best_test_score = test_score
            best_cv_score = cv_scores.mean()
            best_model_name = model_name

    print(f'{text}_케이스 완료\n')

    # 각 케이스별 모델 점수 저장
    All_model_scores[target_column]['scores'][text] = case_model_scores
    # 최고 점수를 가진 모델 정보 저장
    All_model_scores[target_column]['cases_best_scores'][text] = {
        'model_name': best_model_name,
        'test_score': best_test_score,
        'cv_mean_score': best_cv_score,
        'data_range': f'300~{300 + len(data2)}'  # 데이터 범위 추가
    }

    # 전 범위를 테스트하기 위한 설정
    count = 0
    data_len = len(data2)

    while count < len(data[selected_columns][data[target_column] == 0]):

        print(f'훈련 인덱스: {count}~{count + data_len}\n')

        data1 = data[selected_columns][data[target_column] == 0][count:count + data_len]
        data2 = data[selected_columns][data[target_column] == 1]

        if len(data1) == 0 or len(data2) == 0:
            break

        min_len = min(len(data1), len(data2))
        data1 = data1[:min_len]
        data2 = data2[:min_len]

        data3 = pd.concat([data1, data2])
        data_contents = data3[title] + ' ' + data3[text]
        data_labeling = data3[target_column]

        if len(set(data_labeling)) < 2:  # 클래스가 2개 미만이면 넘어가기
            count += data_len
            continue

        if len(data_labeling) < 10:  # 최소 데이터 크기 확인
            print(f"데이터 크기가 너무 작아서 건너뜁니다: {len(data_labeling)}")
            count += data_len
            continue

        X_train, X_test, y_train, y_test = train_test_split(data_contents, data_labeling, stratify=data_labeling, test_size=0.2, random_state=42)

        range_test_scores = {}
        for model_name, pipeline in pipelines.items():
            print(f"{model_name} 전 범위 테스트 중... (타겟: {target_column})")

            X_test_tfidf = pipeline.named_steps['vect'].transform(X_test)
            test_score = pipeline.score(X_test, y_test)
            print(f"{model_name} 테스트 데이터 점수 (전 범위): {test_score:.4f}\n")

            range_test_scores[model_name] = {
                'test_score': test_score,
                'data_range': f'{count}~{count + data_len}'
            }

        All_model_scores[target_column]['range_test_scores'][f'{count}~{count + data_len}'] = range_test_scores
        count += data_len

    # 각 타겟 컬럼별 점수 JSON 파일로 저장
    text_cases_scores_path = os.path.join(model_scores_save_path, f'{target_column}_text_cases_scores.json')
    with open(text_cases_scores_path, 'w', encoding='utf-8') as json_file:
        json.dump(All_model_scores, json_file, ensure_ascii=False, indent=4)

print("모든 모델이 학습되고 저장되었습니다.")
# Out:
# aggr 학습 시작...
#
# extra_trees 학습 중... (타겟: aggr)
# extra_trees - X_train 크기: (819, 10466)
# extra_trees - X_test 크기: (205, 10466)
# extra_trees 학습 데이터 점수: 0.9988
# extra_trees 테스트 데이터 점수: 0.8390
# extra_trees 교차 검증 점수: [0.89634146 0.84756098 0.89634146 0.8902439  0.8404908 ]
# extra_trees 교차 검증 평균 점수: 0.8742
#
# ridge_classifier 학습 중... (타겟: aggr)
# ridge_classifier - X_train 크기: (819, 10466)
# ridge_classifier - X_test 크기: (205, 10466)
# ridge_classifier 학습 데이터 점수: 0.9963
# ridge_classifier 테스트 데이터 점수: 0.8780
# ridge_classifier 교차 검증 점수: [0.88414634 0.86585366 0.85365854 0.87195122 0.85276074]
# ridge_classifier 교차 검증 평균 점수: 0.8657
#
# logistic_regression 학습 중... (타겟: aggr)
# logistic_regression - X_train 크기: (819, 10466)
# logistic_regression - X_test 크기: (205, 10466)
# logistic_regression 학습 데이터 점수: 0.9719
# logistic_regression 테스트 데이터 점수: 0.8927
# logistic_regression 교차 검증 점수: [0.87195122 0.88414634 0.85365854 0.88414634 0.86503067]
# logistic_regression 교차 검증 평균 점수: 0.8718
#
# naive_bayes 학습 중... (타겟: aggr)
# naive_bayes - X_train 크기: (819, 10466)
# naive_bayes - X_test 크기: (205, 10466)
# naive_bayes 학습 데이터 점수: 0.9707
# naive_bayes 테스트 데이터 점수: 0.8293
# naive_bayes 교차 검증 점수: [0.82926829 0.82317073 0.82926829 0.81097561 0.80981595]
# naive_bayes 교차 검증 평균 점수: 0.8205
#
# svm 학습 중... (타겟: aggr)
# svm - X_train 크기: (819, 10466)
# svm - X_test 크기: (205, 10466)
# svm 학습 데이터 점수: 0.9963
# svm 테스트 데이터 점수: 0.8732
# svm 교차 검증 점수: [0.87195122 0.88414634 0.84146341 0.8597561  0.84662577]
# svm 교차 검증 평균 점수: 0.8608
#
# hard_model 학습 중... (타겟: aggr)
# hard_model - X_train 크기: (819, 10466)
# hard_model - X_test 크기: (205, 10466)
# hard_model 학습 데이터 점수: 0.9963
# hard_model 테스트 데이터 점수: 0.8829
# hard_model 교차 검증 점수: [0.8902439  0.8902439  0.87195122 0.87804878 0.86503067]
# hard_model 교차 검증 평균 점수: 0.8791
#
# soft_model 학습 중... (타겟: aggr)
# soft_model - X_train 크기: (819, 10466)
# soft_model - X_test 크기: (205, 10466)
# soft_model 학습 데이터 점수: 0.9976
# soft_model 테스트 데이터 점수: 0.8732
# soft_model 교차 검증 점수: [0.89634146 0.86585366 0.8902439  0.88414634 0.86503067]
# soft_model 교차 검증 평균 점수: 0.8803
#
# text_eomi_giho_essential_morphed_케이스 완료
#
# 훈련 인덱스: 0~512
#
# extra_trees 전 범위 테스트 중... (타겟: aggr)
# extra_trees 테스트 데이터 점수 (전 범위): 0.9268
#
# ridge_classifier 전 범위 테스트 중... (타겟: aggr)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.9122
#
# logistic_regression 전 범위 테스트 중... (타겟: aggr)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.9317
#
# naive_bayes 전 범위 테스트 중... (타겟: aggr)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.8732
#
# svm 전 범위 테스트 중... (타겟: aggr)
# svm 테스트 데이터 점수 (전 범위): 0.9171
#
# hard_model 전 범위 테스트 중... (타겟: aggr)
# hard_model 테스트 데이터 점수 (전 범위): 0.9268
#
# soft_model 전 범위 테스트 중... (타겟: aggr)
# soft_model 테스트 데이터 점수 (전 범위): 0.9220
#
# 훈련 인덱스: 512~1024
#
# extra_trees 전 범위 테스트 중... (타겟: aggr)
# extra_trees 테스트 데이터 점수 (전 범위): 0.9073
#
# ridge_classifier 전 범위 테스트 중... (타겟: aggr)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.9171
#
# logistic_regression 전 범위 테스트 중... (타겟: aggr)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.9220
#
# naive_bayes 전 범위 테스트 중... (타겟: aggr)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.8683
#
# svm 전 범위 테스트 중... (타겟: aggr)
# svm 테스트 데이터 점수 (전 범위): 0.9171
#
# hard_model 전 범위 테스트 중... (타겟: aggr)
# hard_model 테스트 데이터 점수 (전 범위): 0.9268
#
# soft_model 전 범위 테스트 중... (타겟: aggr)
# soft_model 테스트 데이터 점수 (전 범위): 0.9220
#
# 훈련 인덱스: 1024~1536
#
# extra_trees 전 범위 테스트 중... (타겟: aggr)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8195
#
# ridge_classifier 전 범위 테스트 중... (타겟: aggr)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7902
#
# logistic_regression 전 범위 테스트 중... (타겟: aggr)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8049
#
# naive_bayes 전 범위 테스트 중... (타겟: aggr)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6976
#
# svm 전 범위 테스트 중... (타겟: aggr)
# svm 테스트 데이터 점수 (전 범위): 0.7854
#
# hard_model 전 범위 테스트 중... (타겟: aggr)
# hard_model 테스트 데이터 점수 (전 범위): 0.8049
#
# soft_model 전 범위 테스트 중... (타겟: aggr)
# soft_model 테스트 데이터 점수 (전 범위): 0.7854
#
# 훈련 인덱스: 1536~2048
#
# extra_trees 전 범위 테스트 중... (타겟: aggr)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8049
#
# ridge_classifier 전 범위 테스트 중... (타겟: aggr)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8000
#
# logistic_regression 전 범위 테스트 중... (타겟: aggr)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8341
#
# naive_bayes 전 범위 테스트 중... (타겟: aggr)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6732
#
# svm 전 범위 테스트 중... (타겟: aggr)
# svm 테스트 데이터 점수 (전 범위): 0.8098
#
# hard_model 전 범위 테스트 중... (타겟: aggr)
# hard_model 테스트 데이터 점수 (전 범위): 0.8244
#
# soft_model 전 범위 테스트 중... (타겟: aggr)
# soft_model 테스트 데이터 점수 (전 범위): 0.7902
#
# 훈련 인덱스: 2048~2560
#
# extra_trees 전 범위 테스트 중... (타겟: aggr)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7805
#
# ridge_classifier 전 범위 테스트 중... (타겟: aggr)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8049
#
# logistic_regression 전 범위 테스트 중... (타겟: aggr)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8049
#
# naive_bayes 전 범위 테스트 중... (타겟: aggr)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6927
#
# svm 전 범위 테스트 중... (타겟: aggr)
# svm 테스트 데이터 점수 (전 범위): 0.8000
#
# hard_model 전 범위 테스트 중... (타겟: aggr)
# hard_model 테스트 데이터 점수 (전 범위): 0.8195
#
# soft_model 전 범위 테스트 중... (타겟: aggr)
# soft_model 테스트 데이터 점수 (전 범위): 0.7610
#
# 훈련 인덱스: 2560~3072
#
# extra_trees 전 범위 테스트 중... (타겟: aggr)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7756
#
# ridge_classifier 전 범위 테스트 중... (타겟: aggr)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7707
#
# logistic_regression 전 범위 테스트 중... (타겟: aggr)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8146
#
# naive_bayes 전 범위 테스트 중... (타겟: aggr)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6927
#
# svm 전 범위 테스트 중... (타겟: aggr)
# svm 테스트 데이터 점수 (전 범위): 0.7951
#
# hard_model 전 범위 테스트 중... (타겟: aggr)
# hard_model 테스트 데이터 점수 (전 범위): 0.7951
#
# soft_model 전 범위 테스트 중... (타겟: aggr)
# soft_model 테스트 데이터 점수 (전 범위): 0.7756
#
# 훈련 인덱스: 3072~3584
#
# extra_trees 전 범위 테스트 중... (타겟: aggr)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8098
#
# ridge_classifier 전 범위 테스트 중... (타겟: aggr)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7756
#
# logistic_regression 전 범위 테스트 중... (타겟: aggr)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7854
#
# naive_bayes 전 범위 테스트 중... (타겟: aggr)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.7122
#
# svm 전 범위 테스트 중... (타겟: aggr)
# svm 테스트 데이터 점수 (전 범위): 0.7902
#
# hard_model 전 범위 테스트 중... (타겟: aggr)
# hard_model 테스트 데이터 점수 (전 범위): 0.7854
#
# soft_model 전 범위 테스트 중... (타겟: aggr)
# soft_model 테스트 데이터 점수 (전 범위): 0.7902
#
# 훈련 인덱스: 3584~4096
#
# extra_trees 전 범위 테스트 중... (타겟: aggr)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8098
#
# ridge_classifier 전 범위 테스트 중... (타겟: aggr)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8000
#
# logistic_regression 전 범위 테스트 중... (타겟: aggr)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8244
#
# naive_bayes 전 범위 테스트 중... (타겟: aggr)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6927
#
# svm 전 범위 테스트 중... (타겟: aggr)
# svm 테스트 데이터 점수 (전 범위): 0.8000
#
# hard_model 전 범위 테스트 중... (타겟: aggr)
# hard_model 테스트 데이터 점수 (전 범위): 0.8146
#
# soft_model 전 범위 테스트 중... (타겟: aggr)
# soft_model 테스트 데이터 점수 (전 범위): 0.7902
#
# 훈련 인덱스: 4096~4608
#
# extra_trees 전 범위 테스트 중... (타겟: aggr)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8098
#
# ridge_classifier 전 범위 테스트 중... (타겟: aggr)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7805
#
# logistic_regression 전 범위 테스트 중... (타겟: aggr)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8098
#
# naive_bayes 전 범위 테스트 중... (타겟: aggr)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6683
#
# svm 전 범위 테스트 중... (타겟: aggr)
# svm 테스트 데이터 점수 (전 범위): 0.8000
#
# hard_model 전 범위 테스트 중... (타겟: aggr)
# hard_model 테스트 데이터 점수 (전 범위): 0.7951
#
# soft_model 전 범위 테스트 중... (타겟: aggr)
# soft_model 테스트 데이터 점수 (전 범위): 0.7659
#
# 훈련 인덱스: 4608~5120
#
# extra_trees 전 범위 테스트 중... (타겟: aggr)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7805
#
# ridge_classifier 전 범위 테스트 중... (타겟: aggr)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7902
#
# logistic_regression 전 범위 테스트 중... (타겟: aggr)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8098
#
# naive_bayes 전 범위 테스트 중... (타겟: aggr)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6732
#
# svm 전 범위 테스트 중... (타겟: aggr)
# svm 테스트 데이터 점수 (전 범위): 0.8000
#
# hard_model 전 범위 테스트 중... (타겟: aggr)
# hard_model 테스트 데이터 점수 (전 범위): 0.8049
#
# soft_model 전 범위 테스트 중... (타겟: aggr)
# soft_model 테스트 데이터 점수 (전 범위): 0.7854
#
# 훈련 인덱스: 5120~5632
#
# extra_trees 전 범위 테스트 중... (타겟: aggr)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7317
#
# ridge_classifier 전 범위 테스트 중... (타겟: aggr)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7463
#
# logistic_regression 전 범위 테스트 중... (타겟: aggr)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7659
#
# naive_bayes 전 범위 테스트 중... (타겟: aggr)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6634
#
# svm 전 범위 테스트 중... (타겟: aggr)
# svm 테스트 데이터 점수 (전 범위): 0.7463
#
# hard_model 전 범위 테스트 중... (타겟: aggr)
# hard_model 테스트 데이터 점수 (전 범위): 0.7610
#
# soft_model 전 범위 테스트 중... (타겟: aggr)
# soft_model 테스트 데이터 점수 (전 범위): 0.7463
#
# 훈련 인덱스: 5632~6144
#
# extra_trees 전 범위 테스트 중... (타겟: aggr)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7463
#
# ridge_classifier 전 범위 테스트 중... (타겟: aggr)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7707
#
# logistic_regression 전 범위 테스트 중... (타겟: aggr)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7854
#
# naive_bayes 전 범위 테스트 중... (타겟: aggr)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6829
#
# svm 전 범위 테스트 중... (타겟: aggr)
# svm 테스트 데이터 점수 (전 범위): 0.7902
#
# hard_model 전 범위 테스트 중... (타겟: aggr)
# hard_model 테스트 데이터 점수 (전 범위): 0.7902
#
# soft_model 전 범위 테스트 중... (타겟: aggr)
# soft_model 테스트 데이터 점수 (전 범위): 0.7561
#
# 훈련 인덱스: 6144~6656
#
# extra_trees 전 범위 테스트 중... (타겟: aggr)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8049
#
# ridge_classifier 전 범위 테스트 중... (타겟: aggr)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7805
#
# logistic_regression 전 범위 테스트 중... (타겟: aggr)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8000
#
# naive_bayes 전 범위 테스트 중... (타겟: aggr)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6732
#
# svm 전 범위 테스트 중... (타겟: aggr)
# svm 테스트 데이터 점수 (전 범위): 0.8000
#
# hard_model 전 범위 테스트 중... (타겟: aggr)
# hard_model 테스트 데이터 점수 (전 범위): 0.7902
#
# soft_model 전 범위 테스트 중... (타겟: aggr)
# soft_model 테스트 데이터 점수 (전 범위): 0.7707
#
# 훈련 인덱스: 6656~7168
#
# extra_trees 전 범위 테스트 중... (타겟: aggr)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7537
#
# ridge_classifier 전 범위 테스트 중... (타겟: aggr)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7537
#
# logistic_regression 전 범위 테스트 중... (타겟: aggr)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7313
#
# naive_bayes 전 범위 테스트 중... (타겟: aggr)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6343
#
# svm 전 범위 테스트 중... (타겟: aggr)
# svm 테스트 데이터 점수 (전 범위): 0.7910
#
# hard_model 전 범위 테스트 중... (타겟: aggr)
# hard_model 테스트 데이터 점수 (전 범위): 0.7537
#
# soft_model 전 범위 테스트 중... (타겟: aggr)
# soft_model 테스트 데이터 점수 (전 범위): 0.7388
#
# 욕설_모욕 학습 시작...
#
# extra_trees 학습 중... (타겟: 욕설_모욕)
# extra_trees - X_train 크기: (73, 2783)
# extra_trees - X_test 크기: (19, 2783)
# extra_trees 학습 데이터 점수: 1.0000
# extra_trees 테스트 데이터 점수: 0.8421
# extra_trees 교차 검증 점수: [0.86666667 0.8        0.86666667 0.85714286 0.64285714]
# extra_trees 교차 검증 평균 점수: 0.8067
#
# ridge_classifier 학습 중... (타겟: 욕설_모욕)
# ridge_classifier - X_train 크기: (73, 2783)
# ridge_classifier - X_test 크기: (19, 2783)
# ridge_classifier 학습 데이터 점수: 1.0000
# ridge_classifier 테스트 데이터 점수: 0.9474
# ridge_classifier 교차 검증 점수: [0.86666667 0.93333333 0.73333333 0.92857143 0.85714286]
# ridge_classifier 교차 검증 평균 점수: 0.8638
#
# logistic_regression 학습 중... (타겟: 욕설_모욕)
# logistic_regression - X_train 크기: (73, 2783)
# logistic_regression - X_test 크기: (19, 2783)
# logistic_regression 학습 데이터 점수: 1.0000
# logistic_regression 테스트 데이터 점수: 0.9474
# logistic_regression 교차 검증 점수: [0.93333333 0.93333333 0.73333333 0.78571429 0.85714286]
# logistic_regression 교차 검증 평균 점수: 0.8486
#
# naive_bayes 학습 중... (타겟: 욕설_모욕)
# naive_bayes - X_train 크기: (73, 2783)
# naive_bayes - X_test 크기: (19, 2783)
# naive_bayes 학습 데이터 점수: 1.0000
# naive_bayes 테스트 데이터 점수: 0.8421
# naive_bayes 교차 검증 점수: [0.86666667 0.93333333 0.73333333 0.64285714 0.71428571]
# naive_bayes 교차 검증 평균 점수: 0.7781
#
# svm 학습 중... (타겟: 욕설_모욕)
# svm - X_train 크기: (73, 2783)
# svm - X_test 크기: (19, 2783)
# svm 학습 데이터 점수: 1.0000
# svm 테스트 데이터 점수: 0.9474
# svm 교차 검증 점수: [0.86666667 0.93333333 0.73333333 0.78571429 0.71428571]
# svm 교차 검증 평균 점수: 0.8067
#
# hard_model 학습 중... (타겟: 욕설_모욕)
# hard_model - X_train 크기: (73, 2783)
# hard_model - X_test 크기: (19, 2783)
# hard_model 학습 데이터 점수: 1.0000
# hard_model 테스트 데이터 점수: 0.9474
# hard_model 교차 검증 점수: [0.93333333 0.93333333 0.73333333 0.78571429 0.78571429]
# hard_model 교차 검증 평균 점수: 0.8343
#
# soft_model 학습 중... (타겟: 욕설_모욕)
# soft_model - X_train 크기: (73, 2783)
# soft_model - X_test 크기: (19, 2783)
# soft_model 학습 데이터 점수: 1.0000
# soft_model 테스트 데이터 점수: 0.8947
# soft_model 교차 검증 점수: [0.86666667 0.93333333 0.93333333 1.         0.71428571]
# soft_model 교차 검증 평균 점수: 0.8895
#
# text_morphed_masked_케이스 완료
#
# 훈련 인덱스: 0~46
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8421
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 1.0000
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 1.0000
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.8421
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 1.0000
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 1.0000
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.9474
#
# 훈련 인덱스: 46~92
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8421
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.9474
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.9474
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.8947
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.9474
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.9474
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.9474
#
# 훈련 인덱스: 92~138
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8421
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6842
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6842
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6316
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.6842
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.6842
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.6842
#
# 훈련 인덱스: 138~184
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8421
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8421
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7368
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6316
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.7895
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.7895
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7895
#
# 훈련 인덱스: 184~230
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7895
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8947
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8421
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.7368
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.8421
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.8421
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7895
#
# 훈련 인덱스: 230~276
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8421
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.9474
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.9474
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.9474
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.9474
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.9474
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.9474
#
# 훈련 인덱스: 276~322
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7895
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8947
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8947
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.8421
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.8947
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.8947
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.8421
#
# 훈련 인덱스: 322~368
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8421
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 1.0000
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 1.0000
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.8421
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 1.0000
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 1.0000
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.9474
#
# 훈련 인덱스: 368~414
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8421
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 1.0000
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 1.0000
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.9474
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 1.0000
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 1.0000
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.9474
#
# 훈련 인덱스: 414~460
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.6842
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8947
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8947
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.7895
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.8947
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.8947
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.8421
#
# 훈련 인덱스: 460~506
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7895
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.9474
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.9474
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.7368
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.9474
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.9474
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.8947
#
# 훈련 인덱스: 506~552
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7895
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7895
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7895
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6842
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.7895
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.7895
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.8947
#
# 훈련 인덱스: 552~598
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8421
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 1.0000
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 1.0000
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.9474
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 1.0000
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 1.0000
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.9474
#
# 훈련 인덱스: 598~644
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.6842
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6842
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6842
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.5789
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.7368
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.6842
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7368
#
# 훈련 인덱스: 644~690
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.6316
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6842
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6316
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.5789
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.7368
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.6842
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7368
#
# 훈련 인덱스: 690~736
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7895
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7368
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6842
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6842
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.7368
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.7368
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.8421
#
# 훈련 인덱스: 736~782
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7895
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6842
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6842
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6316
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.6842
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.6842
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7895
#
# 훈련 인덱스: 782~828
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7895
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7895
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7368
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.5789
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.8421
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.7895
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.8947
#
# 훈련 인덱스: 828~874
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.6842
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6316
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.5789
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.5789
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.5789
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.5789
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.6316
#
# 훈련 인덱스: 874~920
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7895
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6842
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6842
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6316
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.6842
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.6842
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7895
#
# 훈련 인덱스: 920~966
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.6316
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7368
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6842
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.5263
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.7368
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.7368
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.6842
#
# 훈련 인덱스: 966~1012
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.6842
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6316
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.5789
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.5263
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.6842
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.5789
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7368
#
# 훈련 인덱스: 1012~1058
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.6316
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6316
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6316
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.5789
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.6316
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.6316
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.5789
#
# 훈련 인덱스: 1058~1104
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7368
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7368
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6842
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6842
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.6842
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.6842
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7368
#
# 훈련 인덱스: 1104~1150
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7368
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7368
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7368
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.5789
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.7368
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.7368
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7895
#
# 훈련 인덱스: 1150~1196
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.6842
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6842
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6316
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6316
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.6842
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.6842
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7368
#
# 훈련 인덱스: 1196~1242
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.6316
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6842
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6316
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.5789
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.6842
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.6842
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7368
#
# 훈련 인덱스: 1242~1288
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7368
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7895
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7368
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.4737
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.7368
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.7368
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7368
#
# 훈련 인덱스: 1288~1334
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7895
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7895
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7368
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6316
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.7895
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.7895
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.8421
#
# 훈련 인덱스: 1334~1380
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7368
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7368
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7368
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6842
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.7368
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.7368
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.8421
#
# 훈련 인덱스: 1380~1426
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.6316
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6316
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6316
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.5789
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.7368
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.6316
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7368
#
# 훈련 인덱스: 1426~1472
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8421
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8421
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7895
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6316
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.8421
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.8421
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.8947
#
# 훈련 인덱스: 1472~1518
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7368
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6842
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6842
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6842
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.6842
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.6842
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.6842
#
# 훈련 인덱스: 1518~1564
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.6316
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7368
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7368
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6316
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.7895
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.7368
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.6842
#
# 훈련 인덱스: 1564~1610
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7895
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7368
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7368
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.5263
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.7368
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.7368
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7368
#
# 훈련 인덱스: 1610~1656
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7368
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7368
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7368
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6842
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.7368
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.7368
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7895
#
# 훈련 인덱스: 1656~1702
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.6842
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7895
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7895
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6842
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.7895
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.7895
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7895
#
# 훈련 인덱스: 1702~1748
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.6316
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6842
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6842
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6842
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.6842
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.6842
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.6842
#
# 훈련 인덱스: 1748~1794
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.6316
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6316
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6316
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.5789
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.6316
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.6316
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.6316
#
# 훈련 인덱스: 1794~1840
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7368
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6316
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.5789
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.5789
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.6842
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.6316
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7368
#
# 훈련 인덱스: 1840~1886
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.6316
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.5789
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.5789
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.5263
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.5789
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.5789
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.6842
#
# 훈련 인덱스: 1886~1932
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.6316
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6842
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6842
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6316
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.6842
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.6842
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.6842
#
# 훈련 인덱스: 1932~1978
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.6842
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7895
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7895
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6316
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.7895
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.7895
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7895
#
# 훈련 인덱스: 1978~2024
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8421
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.9474
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.9474
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.9474
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.9474
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.9474
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.8947
#
# 훈련 인덱스: 2024~2070
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7895
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7895
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7895
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.7368
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.7895
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.7895
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.8421
#
# 훈련 인덱스: 2070~2116
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8421
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8947
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8947
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.8947
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.8947
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.8947
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.8421
#
# 훈련 인덱스: 2116~2162
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8421
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.9474
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.9474
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.9474
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.9474
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.9474
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.8947
#
# 훈련 인덱스: 2162~2208
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7895
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.9474
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.9474
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.8421
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.9474
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.9474
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.8947
#
# 훈련 인덱스: 2208~2254
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7895
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7895
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7895
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.7895
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.7895
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.7895
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.8421
#
# 훈련 인덱스: 2254~2300
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.5789
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6842
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6842
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.5789
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.6842
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.6842
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.6316
#
# 훈련 인덱스: 2300~2346
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7895
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7368
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7368
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.7368
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.7368
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.7368
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.8421
#
# 훈련 인덱스: 2346~2392
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7368
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8421
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8421
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.7368
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.8421
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.8421
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.8421
#
# 훈련 인덱스: 2392~2438
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7368
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8421
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8421
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.8421
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.8421
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.8421
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7895
#
# 훈련 인덱스: 2438~2484
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8421
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7368
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7368
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6842
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.7368
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.7368
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.8421
#
# 훈련 인덱스: 2484~2530
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.5789
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6842
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6842
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6842
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.6842
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.6842
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.6842
#
# 훈련 인덱스: 2530~2576
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.6316
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8947
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8947
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6842
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.8947
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.8947
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7895
#
# 훈련 인덱스: 2576~2622
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8421
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8947
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8421
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.7368
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.8421
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.8421
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.8947
#
# 훈련 인덱스: 2622~2668
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7368
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8421
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8421
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.7895
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.8421
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.8421
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.8421
#
# 훈련 인덱스: 2668~2714
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7368
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8421
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7895
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.7895
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.7895
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.7895
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.8421
#
# 훈련 인덱스: 2714~2760
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7368
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8421
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8421
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.7368
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.8421
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.8421
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7895
#
# 훈련 인덱스: 2760~2806
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7368
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8947
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8421
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.7368
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.8947
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.8947
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7895
#
# 훈련 인덱스: 2806~2852
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.5263
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8947
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8421
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6842
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.8947
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.8947
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.8421
#
# 훈련 인덱스: 2852~2898
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7368
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8947
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8421
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.7368
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.8947
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.8421
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7895
#
# 훈련 인덱스: 2898~2944
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7895
#
# ridge_classifier 전 범위 테스트 중... (타겟: 욕설_모욕)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8421
#
# logistic_regression 전 범위 테스트 중... (타겟: 욕설_모욕)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8421
#
# naive_bayes 전 범위 테스트 중... (타겟: 욕설_모욕)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.7368
#
# svm 전 범위 테스트 중... (타겟: 욕설_모욕)
# svm 테스트 데이터 점수 (전 범위): 0.8421
#
# hard_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# hard_model 테스트 데이터 점수 (전 범위): 0.8421
#
# soft_model 전 범위 테스트 중... (타겟: 욕설_모욕)
# soft_model 테스트 데이터 점수 (전 범위): 0.7895
#
# 훈련 인덱스: 2944~2990
#
# extra_trees 전 범위 테스트 중... (타겟: 욕설_모욕)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7895
#
# ...
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8163
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7653
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7551
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.7245
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.7653
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.7653
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.7755
#
# 훈련 인덱스: 735~980
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.6837
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7143
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6735
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6531
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.6837
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.6735
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.6939
#
# 훈련 인덱스: 980~1225
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7755
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7041
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6939
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6224
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.7041
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.7041
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.7245
#
# 훈련 인덱스: 1225~1470
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7755
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6837
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7041
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6327
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.6837
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.6837
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.7041
#
# 훈련 인덱스: 1470~1715
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7653
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7959
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7551
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.7653
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.7959
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.7551
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.7755
#
# 훈련 인덱스: 1715~1960
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7959
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8061
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8061
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.7245
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.7959
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.7959
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.8061
#
# 훈련 인덱스: 1960~2205
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8980
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8878
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8878
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.8469
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.8980
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.8980
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.9082
#
# 훈련 인덱스: 2205~2450
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8469
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8776
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8776
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.8673
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.8878
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.8878
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.8878
#
# 훈련 인덱스: 2450~2695
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7551
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7653
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7959
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.7551
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.7857
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.7755
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.7857
#
# 훈련 인덱스: 2695~2940
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8061
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8265
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8163
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.7245
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.8367
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.8265
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.7755
#
# 훈련 인덱스: 2940~3185
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8061
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8163
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8469
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.8061
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.8163
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.8163
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.8265
#
# 훈련 인덱스: 3185~3430
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8571
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8878
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8878
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.8776
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.8980
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.8878
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.8878
#
# 훈련 인덱스: 3430~3675
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7857
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7959
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7959
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.7857
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.7959
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.7959
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.7959
#
# 훈련 인덱스: 3675~3920
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7143
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6633
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6735
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6327
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.6837
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.6837
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.6735
#
# 훈련 인덱스: 3920~4165
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7653
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6327
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6429
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6020
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.6327
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.6327
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.6837
#
# 훈련 인덱스: 4165~4410
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8367
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8776
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8776
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.8163
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.8878
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.8776
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.8571
#
# 훈련 인덱스: 4410~4655
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7551
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7551
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7347
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6837
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.7347
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.7347
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.7449
#
# 훈련 인덱스: 4655~4900
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7653
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7041
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7245
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6122
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.7245
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.7041
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.7041
#
# 훈련 인덱스: 4900~5145
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7041
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6633
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6531
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.5714
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.6633
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.6531
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.6327
#
# 훈련 인덱스: 5145~5390
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7755
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6837
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6939
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6531
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.6735
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.6837
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.6735
#
# 훈련 인덱스: 5390~5635
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8265
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7653
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7551
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.7551
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.7755
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.7653
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.7653
#
# 훈련 인덱스: 5635~5880
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8367
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8469
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8469
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.8469
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.8673
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.8469
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.8571
#
# 훈련 인덱스: 5880~6125
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.9082
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.8469
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.8673
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.8469
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.8469
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.8469
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.8878
#
# 훈련 인덱스: 6125~6370
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7653
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7755
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7857
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.7755
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.7857
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.7857
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.7755
#
# 훈련 인덱스: 6370~6615
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.7143
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6837
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6939
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.5918
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.6939
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.6837
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.6939
#
# 훈련 인덱스: 6615~6860
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8163
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7449
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7449
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6531
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.7347
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.7347
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.7653
#
# 훈련 인덱스: 6860~7105
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8061
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.7755
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.7653
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.6837
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.7551
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.7755
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.7653
#
# 훈련 인덱스: 7105~7350
#
# extra_trees 전 범위 테스트 중... (타겟: 저격성 민원)
# extra_trees 테스트 데이터 점수 (전 범위): 0.8033
#
# ridge_classifier 전 범위 테스트 중... (타겟: 저격성 민원)
# ridge_classifier 테스트 데이터 점수 (전 범위): 0.6885
#
# logistic_regression 전 범위 테스트 중... (타겟: 저격성 민원)
# logistic_regression 테스트 데이터 점수 (전 범위): 0.6721
#
# naive_bayes 전 범위 테스트 중... (타겟: 저격성 민원)
# naive_bayes 테스트 데이터 점수 (전 범위): 0.5738
#
# svm 전 범위 테스트 중... (타겟: 저격성 민원)
# svm 테스트 데이터 점수 (전 범위): 0.6721
#
# hard_model 전 범위 테스트 중... (타겟: 저격성 민원)
# hard_model 테스트 데이터 점수 (전 범위): 0.6721
#
# soft_model 전 범위 테스트 중... (타겟: 저격성 민원)
# soft_model 테스트 데이터 점수 (전 범위): 0.6721
#
# 모든 모델이 학습되고 저장되었습니다.

# %%
import json
import os

# 각 JSON 파일의 경로를 리스트로 저장
json_files = [
    'C:/Users/USER/Desktop/핵심역량 프로젝트/데이터/모델/scores/all_range_traing/aggr_text_cases_scores.json',
    'C:/Users/USER/Desktop/핵심역량 프로젝트/데이터/모델/scores/all_range_traing/반복_text_cases_scores.json',
    'C:/Users/USER/Desktop/핵심역량 프로젝트/데이터/모델/scores/all_range_traing/비꼼_시비_text_cases_scores.json',
    'C:/Users/USER/Desktop/핵심역량 프로젝트/데이터/모델/scores/all_range_traing/요지불명_text_cases_scores.json',
    'C:/Users/USER/Desktop/핵심역량 프로젝트/데이터/모델/scores/all_range_traing/욕설_모욕_text_cases_scores.json',
    'C:/Users/USER/Desktop/핵심역량 프로젝트/데이터/모델/scores/all_range_traing/저격성 민원_text_cases_scores.json'
]

# 합칠 모든 데이터를 저장할 딕셔너리
combined_data = {}

# 각 JSON 파일을 읽어서 합치기
for json_file in json_files:
    with open(json_file, 'r', encoding='utf-8') as file:
        data = json.load(file)
        combined_data.update(data)

# 합친 결과를 새로운 JSON 파일로 저장
combined_json_path = 'C:/Users/USER/Desktop/핵심역량 프로젝트/데이터/모델/scores/all_range_traing/combined_text_cases_scores.json'
with open(combined_json_path, 'w', encoding='utf-8') as file:
    json.dump(combined_data, file, ensure_ascii=False, indent=4)

print("모든 JSON 파일이 하나로 합쳐졌습니다.")
# Out:
# 모든 JSON 파일이 하나로 합쳐졌습니다.

# %%
import json
import os
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import ExtraTreesClassifier, VotingClassifier
from sklearn.linear_model import RidgeClassifier, LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, cross_val_score
import joblib
import pandas as pd

model_scores_save_path = 'C:/Users/USER/Desktop/핵심역량 프로젝트/데이터/모델/scores/add/'

# Initialize the dictionary with 'scores' and 'cases_best_scores' keys
All_model_scores = {'scores': {}, 'cases_best_scores': {}}

target_column = 'aggr'

for title, text in zip(titles, texts):
    
    selected_columns = [f'{title}', f'{text}', 'aggr', '욕설_모욕', '비꼼_시비', '반복', '요지불명', '저격성 민원']
    data1 = data[selected_columns][data[target_column] == 0]
    data2 = data[selected_columns][data[target_column] == 1]
    data1 = data1[300:300+len(data2)]
    data2 = data2

    data3 = pd.concat([data1, data2])
    data_contents = data3[f'{title}'] + ' ' + data3[f'{text}']
    data_labeling = data3[target_column]

    X_train, X_test, y_train, y_test = train_test_split(data_contents, data_labeling, stratify=data_labeling, test_size=0.2, random_state=42)

    pipelines = {
        'extra_trees': Pipeline([
            ('vect', CountVectorizer()),  # TF-IDF -> Count
            ('et', ExtraTreesClassifier())
        ]),
        'ridge_classifier': Pipeline([
            ('vect', CountVectorizer()),  # TF-IDF -> Count
            ('ridge', RidgeClassifier())
        ]),
        'logistic_regression': Pipeline([
            ('vect', CountVectorizer()),  # TF-IDF -> Count
            ('lr', LogisticRegression())
        ]),
        'naive_bayes': Pipeline([
            ('vect', CountVectorizer()),  # TF-IDF -> Count
            ('nb', MultinomialNB())
        ]),
        'svm': Pipeline([
            ('vect', CountVectorizer()),  # TF-IDF -> Count
            ('svm', SVC())
        ]),
        'hard_model': Pipeline([
            ('vect', CountVectorizer()),  # TF-IDF -> Count
            ('hard_model', VotingClassifier([('LR', LogisticRegression()), ('ridge', RidgeClassifier()), ('svm', SVC()), ('et', ExtraTreesClassifier()), ('nb', MultinomialNB())], voting='hard'))
        ]),
        'soft_model': Pipeline([
            ('vect', CountVectorizer()),  # TF-IDF -> Count
            ('soft_model', VotingClassifier([('LR', LogisticRegression()), ('svm', SVC(probability=True)), ('et', ExtraTreesClassifier()), ('nb', MultinomialNB())], voting='soft'))
        ])
    }

    case_model_scores = {}
    best_model_name = None
    best_test_score = 0
    best_cv_score = 0

    # 모델 훈련 및 평가
    for model_name, pipeline in pipelines.items():
        print(f"Training {model_name}...")

        X_train_count = pipeline.named_steps['vect'].fit_transform(X_train)
        X_test_count = pipeline.named_steps['vect'].transform(X_test)

        print(f"{model_name} - X_train shape: {X_train_count.shape}")
        print(f"{model_name} - X_test shape: {X_test_count.shape}")

        pipeline.fit(X_train, y_train)

        cv_scores = cross_val_score(pipeline, X_train, y_train, cv=5, scoring='accuracy')

        train_score = pipeline.score(X_train, y_train)
        test_score = pipeline.score(X_test, y_test)
        print(f"{model_name} Train set score: {train_score:.4f}")
        print(f"{model_name} Test set score: {test_score:.4f}")
        print(f"{model_name} Cross-validation scores: {cv_scores}")
        print(f"{model_name} Cross-validation mean score: {cv_scores.mean():.4f}\n")

        model_save_path = os.path.join('C:/Users/USER/Desktop/핵심역량 프로젝트/데이터/모델/', f'{text}_{model_name}_count_model.pkl')
        joblib.dump(pipeline, model_save_path)
        case_model_scores[model_name] = {
            'test_score': test_score,
            'cv_scores': cv_scores.tolist(),  # Convert numpy array to list for JSON serialization
            'cv_mean_score': cv_scores.mean()
        }

        # 최고 점수 갱신
        if test_score > best_test_score:
            best_test_score = test_score
            best_cv_score = cv_scores.mean()
            best_model_name = model_name

    print(f'{text}_case_complete')

    # 각 케이스별 모델 점수 저장
    All_model_scores['scores'][text] = case_model_scores
    # 최고 점수를 가진 모델 정보 저장
    All_model_scores['cases_best_scores'][text] = {
        'model_name': best_model_name,
        'test_score': best_test_score,
        'cv_mean_score': best_cv_score
    }

text_cases_scores_path = os.path.join(model_scores_save_path, f'{target_column}_countvec_text_cases_scores.json')
with open(f'{text_cases_scores_path}', 'w', encoding='utf-8') as json_file:
    json.dump(All_model_scores, json_file, ensure_ascii=False, indent=4)

print("All models have been trained and saved.")
# Out:
# Training extra_trees...
# extra_trees - X_train shape: (819, 11590)
# extra_trees - X_test shape: (205, 11590)
# extra_trees Train set score: 0.9988
# extra_trees Test set score: 0.8146
# extra_trees Cross-validation scores: [0.87195122 0.7804878  0.85365854 0.87804878 0.79141104]
# extra_trees Cross-validation mean score: 0.8351
#
# Training ridge_classifier...
# ridge_classifier - X_train shape: (819, 11590)
# ridge_classifier - X_test shape: (205, 11590)
# ridge_classifier Train set score: 0.9988
# ridge_classifier Test set score: 0.8000
# ridge_classifier Cross-validation scores: [0.75       0.80487805 0.7804878  0.81097561 0.79754601]
# ridge_classifier Cross-validation mean score: 0.7888
#
# Training logistic_regression...
# logistic_regression - X_train shape: (819, 11590)
# logistic_regression - X_test shape: (205, 11590)
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# logistic_regression Train set score: 0.9988
# logistic_regression Test set score: 0.8732
# logistic_regression Cross-validation scores: [0.84146341 0.8597561  0.86585366 0.87195122 0.83435583]
# logistic_regression Cross-validation mean score: 0.8547
#
# Training naive_bayes...
# naive_bayes - X_train shape: (819, 11590)
# naive_bayes - X_test shape: (205, 11590)
# naive_bayes Train set score: 0.9792
# naive_bayes Test set score: 0.8488
# naive_bayes Cross-validation scores: [0.85365854 0.81097561 0.81097561 0.85365854 0.82208589]
# naive_bayes Cross-validation mean score: 0.8303
#
# Training svm...
# svm - X_train shape: (819, 11590)
# svm - X_test shape: (205, 11590)
# svm Train set score: 0.9365
# svm Test set score: 0.8146
# svm Cross-validation scores: [0.82926829 0.80487805 0.80487805 0.85365854 0.77300613]
# svm Cross-validation mean score: 0.8131
#
# Training hard_model...
# hard_model - X_train shape: (819, 11590)
# hard_model - X_test shape: (205, 11590)
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# hard_model Train set score: 0.9988
# hard_model Test set score: 0.8537
# hard_model Cross-validation scores: [0.85365854 0.84756098 0.85365854 0.8902439  0.84662577]
# hard_model Cross-validation mean score: 0.8583
#
# Training soft_model...
# soft_model - X_train shape: (819, 11590)
# soft_model - X_test shape: (205, 11590)
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# soft_model Train set score: 0.9963
# soft_model Test set score: 0.8732
# soft_model Cross-validation scores: [0.88414634 0.85365854 0.8597561  0.89634146 0.84662577]
# soft_model Cross-validation mean score: 0.8681
#
# text_morphed_case_complete
# Training extra_trees...
# extra_trees - X_train shape: (819, 10326)
# extra_trees - X_test shape: (205, 10326)
# extra_trees Train set score: 0.9988
# extra_trees Test set score: 0.8244
# extra_trees Cross-validation scores: [0.82926829 0.7804878  0.84756098 0.84146341 0.77300613]
# extra_trees Cross-validation mean score: 0.8144
#
# Training ridge_classifier...
# ridge_classifier - X_train shape: (819, 10326)
# ridge_classifier - X_test shape: (205, 10326)
# ridge_classifier Train set score: 0.9988
# ridge_classifier Test set score: 0.7610
# ridge_classifier Cross-validation scores: [0.78658537 0.82926829 0.76829268 0.81097561 0.79141104]
# ridge_classifier Cross-validation mean score: 0.7973
#
# Training logistic_regression...
# logistic_regression - X_train shape: (819, 10326)
# logistic_regression - X_test shape: (205, 10326)
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# logistic_regression Train set score: 0.9988
# logistic_regression Test set score: 0.8341
# logistic_regression Cross-validation scores: [0.82926829 0.8597561  0.84146341 0.87804878 0.82822086]
# logistic_regression Cross-validation mean score: 0.8474
#
# Training naive_bayes...
# naive_bayes - X_train shape: (819, 10326)
# naive_bayes - X_test shape: (205, 10326)
# naive_bayes Train set score: 0.9756
# naive_bayes Test set score: 0.8585
# naive_bayes Cross-validation scores: [0.84756098 0.81707317 0.80487805 0.82317073 0.81595092]
# naive_bayes Cross-validation mean score: 0.8217
#
# Training svm...
# svm - X_train shape: (819, 10326)
# svm - X_test shape: (205, 10326)
# svm Train set score: 0.9377
# svm Test set score: 0.8098
# svm Cross-validation scores: [0.79268293 0.79268293 0.76829268 0.82926829 0.76687117]
# svm Cross-validation mean score: 0.7900
#
# Training hard_model...
# hard_model - X_train shape: (819, 10326)
# hard_model - X_test shape: (205, 10326)
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# hard_model Train set score: 0.9988
# hard_model Test set score: 0.8634
# hard_model Cross-validation scores: [0.83536585 0.8597561  0.85365854 0.86585366 0.81595092]
# hard_model Cross-validation mean score: 0.8461
#
# Training soft_model...
# soft_model - X_train shape: (819, 10326)
# soft_model - X_test shape: (205, 10326)
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# soft_model Train set score: 0.9951
# soft_model Test set score: 0.8585
# soft_model Cross-validation scores: [0.84756098 0.85365854 0.8597561  0.87804878 0.85276074]
# soft_model Cross-validation mean score: 0.8584
#
# text_essential_morphed_case_complete
# Training extra_trees...
# extra_trees - X_train shape: (819, 2925)
# extra_trees - X_test shape: (205, 2925)
# extra_trees Train set score: 0.9976
# extra_trees Test set score: 0.7854
# extra_trees Cross-validation scores: [0.78658537 0.76219512 0.80487805 0.81707317 0.79754601]
# extra_trees Cross-validation mean score: 0.7937
#
# Training ridge_classifier...
# ridge_classifier - X_train shape: (819, 2925)
# ridge_classifier - X_test shape: (205, 2925)
# ridge_classifier Train set score: 0.9963
# ridge_classifier Test set score: 0.7073
# ridge_classifier Cross-validation scores: [0.70731707 0.70121951 0.73170732 0.7195122  0.74846626]
# ridge_classifier Cross-validation mean score: 0.7216
#
# Training logistic_regression...
# logistic_regression - X_train shape: (819, 2925)
# logistic_regression - X_test shape: (205, 2925)
# logistic_regression Train set score: 0.9853
# logistic_regression Test set score: 0.7512
# logistic_regression Cross-validation scores: [0.75609756 0.77439024 0.79268293 0.81097561 0.79141104]
# logistic_regression Cross-validation mean score: 0.7851
#
# Training naive_bayes...
# naive_bayes - X_train shape: (819, 2925)
# naive_bayes - X_test shape: (205, 2925)
# naive_bayes Train set score: 0.9096
# naive_bayes Test set score: 0.7951
# naive_bayes Cross-validation scores: [0.73780488 0.81707317 0.79268293 0.73170732 0.76687117]
# naive_bayes Cross-validation mean score: 0.7692
#
# Training svm...
# svm - X_train shape: (819, 2925)
# svm - X_test shape: (205, 2925)
# svm Train set score: 0.9255
# svm Test set score: 0.7854
# svm Cross-validation scores: [0.75       0.73780488 0.7804878  0.79268293 0.74846626]
# svm Cross-validation mean score: 0.7619
#
# Training hard_model...
# hard_model - X_train shape: (819, 2925)
# hard_model - X_test shape: (205, 2925)
# hard_model Train set score: 0.9915
# hard_model Test set score: 0.8000
# hard_model Cross-validation scores: [0.77439024 0.78658537 0.81097561 0.79878049 0.79754601]
# hard_model Cross-validation mean score: 0.7937
#
# Training soft_model...
# soft_model - X_train shape: (819, 2925)
# soft_model - X_test shape: (205, 2925)
# soft_model Train set score: 0.9902
# soft_model Test set score: 0.8146
# soft_model Cross-validation scores: [0.78658537 0.80487805 0.83536585 0.80487805 0.78527607]
# soft_model Cross-validation mean score: 0.8034
#
# text_removeNN_essential_morphed_case_complete
# Training extra_trees...
# extra_trees - X_train shape: (819, 10466)
# extra_trees - X_test shape: (205, 10466)
# extra_trees Train set score: 0.9988
# extra_trees Test set score: 0.8244
# extra_trees Cross-validation scores: [0.87195122 0.81097561 0.86585366 0.87195122 0.79141104]
# extra_trees Cross-validation mean score: 0.8424
#
# Training ridge_classifier...
# ridge_classifier - X_train shape: (819, 10466)
# ridge_classifier - X_test shape: (205, 10466)
# ridge_classifier Train set score: 0.9988
# ridge_classifier Test set score: 0.7561
# ridge_classifier Cross-validation scores: [0.76829268 0.79268293 0.79878049 0.81707317 0.7791411 ]
# ridge_classifier Cross-validation mean score: 0.7912
#
# Training logistic_regression...
# logistic_regression - X_train shape: (819, 10466)
# logistic_regression - X_test shape: (205, 10466)
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# logistic_regression Train set score: 0.9988
# logistic_regression Test set score: 0.8488
# logistic_regression Cross-validation scores: [0.84756098 0.86585366 0.8597561  0.88414634 0.8404908 ]
# logistic_regression Cross-validation mean score: 0.8596
#
# Training naive_bayes...
# naive_bayes - X_train shape: (819, 10466)
# naive_bayes - X_test shape: (205, 10466)
# naive_bayes Train set score: 0.9780
# naive_bayes Test set score: 0.8683
# naive_bayes Cross-validation scores: [0.86585366 0.80487805 0.81707317 0.84146341 0.82822086]
# naive_bayes Cross-validation mean score: 0.8315
#
# Training svm...
# svm - X_train shape: (819, 10466)
# svm - X_test shape: (205, 10466)
# svm Train set score: 0.9353
# svm Test set score: 0.8146
# svm Cross-validation scores: [0.82926829 0.78658537 0.7804878  0.85365854 0.78527607]
# svm Cross-validation mean score: 0.8071
#
# Training hard_model...
# hard_model - X_train shape: (819, 10466)
# hard_model - X_test shape: (205, 10466)
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# hard_model Train set score: 0.9988
# hard_model Test set score: 0.8537
# hard_model Cross-validation scores: [0.8597561  0.84756098 0.87195122 0.88414634 0.84662577]
# hard_model Cross-validation mean score: 0.8620
#
# Training soft_model...
# soft_model - X_train shape: (819, 10466)
# soft_model - X_test shape: (205, 10466)
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# soft_model Train set score: 0.9963
# soft_model Test set score: 0.8829
# soft_model Cross-validation scores: [0.8902439  0.86585366 0.89634146 0.88414634 0.85276074]
# soft_model Cross-validation mean score: 0.8779
#
# text_eomi_giho_essential_morphed_case_complete
# Training extra_trees...
# extra_trees - X_train shape: (819, 3066)
# extra_trees - X_test shape: (205, 3066)
# extra_trees Train set score: 0.9988
# extra_trees Test set score: 0.8146
# extra_trees Cross-validation scores: [0.81707317 0.80487805 0.82926829 0.84146341 0.81595092]
# extra_trees Cross-validation mean score: 0.8217
#
# Training ridge_classifier...
# ridge_classifier - X_train shape: (819, 3066)
# ridge_classifier - X_test shape: (205, 3066)
# ridge_classifier Train set score: 0.9963
# ridge_classifier Test set score: 0.7268
# ridge_classifier Cross-validation scores: [0.7195122  0.70121951 0.72560976 0.77439024 0.74233129]
# ridge_classifier Cross-validation mean score: 0.7326
#
# Training logistic_regression...
# logistic_regression - X_train shape: (819, 3066)
# logistic_regression - X_test shape: (205, 3066)
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# logistic_regression Train set score: 0.9866
# logistic_regression Test set score: 0.8049
# logistic_regression Cross-validation scores: [0.76219512 0.78658537 0.83536585 0.81097561 0.82208589]
# logistic_regression Cross-validation mean score: 0.8034
#
# Training naive_bayes...
# naive_bayes - X_train shape: (819, 3066)
# naive_bayes - X_test shape: (205, 3066)
# naive_bayes Train set score: 0.9060
# naive_bayes Test set score: 0.7951
# naive_bayes Cross-validation scores: [0.79268293 0.82317073 0.79268293 0.7195122  0.79754601]
# naive_bayes Cross-validation mean score: 0.7851
#
# Training svm...
# svm - X_train shape: (819, 3066)
# svm - X_test shape: (205, 3066)
# svm Train set score: 0.9035
# svm Test set score: 0.7902
# svm Cross-validation scores: [0.75609756 0.76829268 0.82317073 0.83536585 0.80981595]
# svm Cross-validation mean score: 0.7985
#
# Training hard_model...
# hard_model - X_train shape: (819, 3066)
# hard_model - X_test shape: (205, 3066)
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# hard_model Train set score: 0.9902
# hard_model Test set score: 0.8146
# hard_model Cross-validation scores: [0.76219512 0.80487805 0.84146341 0.84756098 0.82822086]
# hard_model Cross-validation mean score: 0.8169
#
# Training soft_model...
# soft_model - X_train shape: (819, 3066)
# soft_model - X_test shape: (205, 3066)
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# soft_model Train set score: 0.9890
# soft_model Test set score: 0.8146
# soft_model Cross-validation scores: [0.82317073 0.83536585 0.83536585 0.82926829 0.85276074]
# soft_model Cross-validation mean score: 0.8352
#
# text_eomi_giho_essential_removeNN_morphed_case_complete
# Training extra_trees...
# extra_trees - X_train shape: (819, 11061)
# extra_trees - X_test shape: (205, 11061)
# extra_trees Train set score: 0.9988
# extra_trees Test set score: 0.8537
# extra_trees Cross-validation scores: [0.84146341 0.79268293 0.84756098 0.85365854 0.79141104]
# extra_trees Cross-validation mean score: 0.8254
#
# Training ridge_classifier...
# ridge_classifier - X_train shape: (819, 11061)
# ridge_classifier - X_test shape: (205, 11061)
# ridge_classifier Train set score: 0.9988
# ridge_classifier Test set score: 0.7707
# ridge_classifier Cross-validation scores: [0.73780488 0.7804878  0.75       0.81707317 0.7791411 ]
# ridge_classifier Cross-validation mean score: 0.7729
#
# Training logistic_regression...
# logistic_regression - X_train shape: (819, 11061)
# logistic_regression - X_test shape: (205, 11061)
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# logistic_regression Train set score: 0.9988
# logistic_regression Test set score: 0.8634
# logistic_regression Cross-validation scores: [0.82926829 0.81097561 0.84756098 0.86585366 0.81595092]
# logistic_regression Cross-validation mean score: 0.8339
#
# Training naive_bayes...
# naive_bayes - X_train shape: (819, 11061)
# naive_bayes - X_test shape: (205, 11061)
# naive_bayes Train set score: 0.9768
# naive_bayes Test set score: 0.8488
# naive_bayes Cross-validation scores: [0.84756098 0.80487805 0.80487805 0.82926829 0.81595092]
# naive_bayes Cross-validation mean score: 0.8205
#
# Training svm...
# svm - X_train shape: (819, 11061)
# svm - X_test shape: (205, 11061)
# svm Train set score: 0.9280
# svm Test set score: 0.8146
# svm Cross-validation scores: [0.82926829 0.78658537 0.79268293 0.84756098 0.77300613]
# svm Cross-validation mean score: 0.8058
#
# Training hard_model...
# hard_model - X_train shape: (819, 11061)
# hard_model - X_test shape: (205, 11061)
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# hard_model Train set score: 0.9988
# hard_model Test set score: 0.8537
# hard_model Cross-validation scores: [0.8597561  0.83536585 0.85365854 0.88414634 0.83435583]
# hard_model Cross-validation mean score: 0.8535
#
# Training soft_model...
# soft_model - X_train shape: (819, 11061)
# soft_model - X_test shape: (205, 11061)
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# soft_model Train set score: 0.9963
# soft_model Test set score: 0.8634
# soft_model Cross-validation scores: [0.86585366 0.84756098 0.8597561  0.88414634 0.8404908 ]
# soft_model Cross-validation mean score: 0.8596
#
# text_morphed_masked_case_complete
# Training extra_trees...
# extra_trees - X_train shape: (819, 9873)
# extra_trees - X_test shape: (205, 9873)
# extra_trees Train set score: 0.9988
# extra_trees Test set score: 0.8098
# extra_trees Cross-validation scores: [0.82317073 0.80487805 0.84756098 0.83536585 0.79141104]
# extra_trees Cross-validation mean score: 0.8205
#
# Training ridge_classifier...
# ridge_classifier - X_train shape: (819, 9873)
# ridge_classifier - X_test shape: (205, 9873)
# ridge_classifier Train set score: 0.9988
# ridge_classifier Test set score: 0.7463
# ridge_classifier Cross-validation scores: [0.75609756 0.7804878  0.75609756 0.81707317 0.7791411 ]
# ridge_classifier Cross-validation mean score: 0.7778
#
# Training logistic_regression...
# logistic_regression - X_train shape: (819, 9873)
# logistic_regression - X_test shape: (205, 9873)
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# logistic_regression Train set score: 0.9976
# logistic_regression Test set score: 0.8244
# logistic_regression Cross-validation scores: [0.79878049 0.81097561 0.84146341 0.84756098 0.82208589]
# logistic_regression Cross-validation mean score: 0.8242
#
# Training naive_bayes...
# naive_bayes - X_train shape: (819, 9873)
# naive_bayes - X_test shape: (205, 9873)
# naive_bayes Train set score: 0.9707
# naive_bayes Test set score: 0.8634
# naive_bayes Cross-validation scores: [0.83536585 0.82317073 0.78658537 0.80487805 0.79141104]
# naive_bayes Cross-validation mean score: 0.8083
#
# Training svm...
# svm - X_train shape: (819, 9873)
# svm - X_test shape: (205, 9873)
# svm Train set score: 0.9243
# svm Test set score: 0.7902
# svm Cross-validation scores: [0.79268293 0.79268293 0.75609756 0.83536585 0.74233129]
# svm Cross-validation mean score: 0.7838
#
# Training hard_model...
# hard_model - X_train shape: (819, 9873)
# hard_model - X_test shape: (205, 9873)
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# soft_model Train set score: 0.9939
# soft_model Test set score: 0.8683
# soft_model Cross-validation scores: [0.83536585 0.8597561  0.85365854 0.8597561  0.82208589]
# soft_model Cross-validation mean score: 0.8461
#
# text_essential_morphed_masked_case_complete
# Training extra_trees...
# extra_trees - X_train shape: (819, 2925)
# extra_trees - X_test shape: (205, 2925)
# extra_trees Train set score: 0.9976
# extra_trees Test set score: 0.7902
# extra_trees Cross-validation scores: [0.76829268 0.76219512 0.78658537 0.83536585 0.80368098]
# extra_trees Cross-validation mean score: 0.7912
#
# Training ridge_classifier...
# ridge_classifier - X_train shape: (819, 2925)
# ridge_classifier - X_test shape: (205, 2925)
# ridge_classifier Train set score: 0.9963
# ridge_classifier Test set score: 0.7073
# ridge_classifier Cross-validation scores: [0.70731707 0.70121951 0.73170732 0.7195122  0.74846626]
# ridge_classifier Cross-validation mean score: 0.7216
#
# Training logistic_regression...
# logistic_regression - X_train shape: (819, 2925)
# logistic_regression - X_test shape: (205, 2925)
# logistic_regression Train set score: 0.9853
# logistic_regression Test set score: 0.7512
# logistic_regression Cross-validation scores: [0.75609756 0.77439024 0.79268293 0.81097561 0.79141104]
# logistic_regression Cross-validation mean score: 0.7851
#
# Training naive_bayes...
# naive_bayes - X_train shape: (819, 2925)
# naive_bayes - X_test shape: (205, 2925)
# naive_bayes Train set score: 0.9096
# naive_bayes Test set score: 0.7951
# naive_bayes Cross-validation scores: [0.73780488 0.81707317 0.79268293 0.73170732 0.76687117]
# naive_bayes Cross-validation mean score: 0.7692
#
# Training svm...
# svm - X_train shape: (819, 2925)
# svm - X_test shape: (205, 2925)
# svm Train set score: 0.9255
# svm Test set score: 0.7854
# svm Cross-validation scores: [0.75       0.73780488 0.7804878  0.79268293 0.74846626]
# svm Cross-validation mean score: 0.7619
#
# Training hard_model...
# hard_model - X_train shape: (819, 2925)
# hard_model - X_test shape: (205, 2925)
# hard_model Train set score: 0.9915
# hard_model Test set score: 0.7951
# hard_model Cross-validation scores: [0.7804878  0.7804878  0.81707317 0.80487805 0.80368098]
# hard_model Cross-validation mean score: 0.7973
#
# Training soft_model...
# soft_model - X_train shape: (819, 2925)
# soft_model - X_test shape: (205, 2925)
# soft_model Train set score: 0.9902
# soft_model Test set score: 0.8146
# soft_model Cross-validation scores: [0.79268293 0.79878049 0.83536585 0.80487805 0.79754601]
# soft_model Cross-validation mean score: 0.8059
#
# text_removeNN_essential_morphed_masked_case_complete
# Training extra_trees...
# extra_trees - X_train shape: (819, 10013)
# extra_trees - X_test shape: (205, 10013)
# extra_trees Train set score: 0.9988
# extra_trees Test set score: 0.8293
# extra_trees Cross-validation scores: [0.82926829 0.79268293 0.88414634 0.86585366 0.78527607]
# extra_trees Cross-validation mean score: 0.8314
#
# Training ridge_classifier...
# ridge_classifier - X_train shape: (819, 10013)
# ridge_classifier - X_test shape: (205, 10013)
# ridge_classifier Train set score: 0.9988
# ridge_classifier Test set score: 0.7707
# ridge_classifier Cross-validation scores: [0.76829268 0.77439024 0.76829268 0.83536585 0.78527607]
# ridge_classifier Cross-validation mean score: 0.7863
#
# Training logistic_regression...
# logistic_regression - X_train shape: (819, 10013)
# logistic_regression - X_test shape: (205, 10013)
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# logistic_regression Train set score: 0.9988
# logistic_regression Test set score: 0.8341
# logistic_regression Cross-validation scores: [0.82926829 0.84756098 0.8597561  0.88414634 0.83435583]
# logistic_regression Cross-validation mean score: 0.8510
#
# Training naive_bayes...
# naive_bayes - X_train shape: (819, 10013)
# naive_bayes - X_test shape: (205, 10013)
# naive_bayes Train set score: 0.9719
# naive_bayes Test set score: 0.8585
# naive_bayes Cross-validation scores: [0.8597561  0.80487805 0.79878049 0.81707317 0.80368098]
# naive_bayes Cross-validation mean score: 0.8168
#
# Training svm...
# svm - X_train shape: (819, 10013)
# svm - X_test shape: (205, 10013)
# svm Train set score: 0.9304
# svm Test set score: 0.8195
# svm Cross-validation scores: [0.81707317 0.78658537 0.77439024 0.86585366 0.7607362 ]
# svm Cross-validation mean score: 0.8009
#
# Training hard_model...
# hard_model - X_train shape: (819, 10013)
# hard_model - X_test shape: (205, 10013)
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# hard_model Train set score: 0.9988
# hard_model Test set score: 0.8439
# hard_model Cross-validation scores: [0.85365854 0.8597561  0.87195122 0.88414634 0.82822086]
# hard_model Cross-validation mean score: 0.8595
#
# Training soft_model...
# soft_model - X_train shape: (819, 10013)
# soft_model - X_test shape: (205, 10013)
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# soft_model Train set score: 0.9963
# soft_model Test set score: 0.8439
# soft_model Cross-validation scores: [0.87804878 0.8597561  0.8902439  0.8597561  0.8404908 ]
# soft_model Cross-validation mean score: 0.8657
#
# text_eomi_giho_essential_morphed_masked_case_complete
# Training extra_trees...
# extra_trees - X_train shape: (819, 3066)
# extra_trees - X_test shape: (205, 3066)
# extra_trees Train set score: 0.9988
# extra_trees Test set score: 0.8244
# extra_trees Cross-validation scores: [0.81097561 0.79878049 0.81707317 0.81707317 0.80368098]
# extra_trees Cross-validation mean score: 0.8095
#
# Training ridge_classifier...
# ridge_classifier - X_train shape: (819, 3066)
# ridge_classifier - X_test shape: (205, 3066)
# ridge_classifier Train set score: 0.9963
# ridge_classifier Test set score: 0.7268
# ridge_classifier Cross-validation scores: [0.7195122  0.70121951 0.72560976 0.77439024 0.74233129]
# ridge_classifier Cross-validation mean score: 0.7326
#
# Training logistic_regression...
# logistic_regression - X_train shape: (819, 3066)
# logistic_regression - X_test shape: (205, 3066)
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# logistic_regression Train set score: 0.9866
# logistic_regression Test set score: 0.8049
# logistic_regression Cross-validation scores: [0.76219512 0.78658537 0.83536585 0.81097561 0.82208589]
# logistic_regression Cross-validation mean score: 0.8034
#
# Training naive_bayes...
# naive_bayes - X_train shape: (819, 3066)
# naive_bayes - X_test shape: (205, 3066)
# naive_bayes Train set score: 0.9060
# naive_bayes Test set score: 0.7951
# naive_bayes Cross-validation scores: [0.79268293 0.82317073 0.79268293 0.7195122  0.79754601]
# naive_bayes Cross-validation mean score: 0.7851
#
# Training svm...
# svm - X_train shape: (819, 3066)
# svm - X_test shape: (205, 3066)
# svm Train set score: 0.9035
# svm Test set score: 0.7902
# svm Cross-validation scores: [0.75609756 0.76829268 0.82317073 0.83536585 0.80981595]
# svm Cross-validation mean score: 0.7985
#
# Training hard_model...
# hard_model - X_train shape: (819, 3066)
# hard_model - X_test shape: (205, 3066)
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# hard_model Train set score: 0.9902
# hard_model Test set score: 0.8146
# hard_model Cross-validation scores: [0.77439024 0.79878049 0.82926829 0.84756098 0.84662577]
# hard_model Cross-validation mean score: 0.8193
#
# Training soft_model...
# soft_model - X_train shape: (819, 3066)
# soft_model - X_test shape: (205, 3066)
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# soft_model Train set score: 0.9890
# soft_model Test set score: 0.8244
# soft_model Cross-validation scores: [0.81707317 0.83536585 0.83536585 0.82317073 0.85889571]
# soft_model Cross-validation mean score: 0.8340
#
# text_eomi_giho_essential_removeNN_morphed_masked_case_complete
# All models have been trained and saved.

# %% [markdown]
# ## TfidfVectorizer 명사제거, 마스킹 X, 파라미터 default - 0726

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.pipeline import Pipeline
from sklearn.ensemble import VotingClassifier
import joblib

# 데이터 불러오기
os.chdir('C:/Users/USER/Desktop/핵심역량 프로젝트/데이터/라벨링 데이터')

data1 = pd.read_csv('0726_masking_labeling_data_0.csv')
data2 = pd.read_csv('0726_masking_labeling_data_1.csv')

data1 = data1.rename(columns={'text_remove_noun_morphed':'text_remove_noun_morphed'})
data2 = data2.rename(columns={'text_remove_noun_morphed':'text_remove_noun_morphed'})

data1 = data1.rename(columns={'저격성 민원':'저격성민원_'})
data2 = data2.rename(columns={'저격성 민원':'저격성민원_'})

selected_columns1 = ['text_remove_noun_morphed', 'aggr', '욕설_모욕', '비꼼_시비', '성희롱', '요지불명', '저격성민원_']
data1 = data1[selected_columns1]
data2 = data2[selected_columns1]
data1 = data1[:366]
data2 = data2[data2.aggr == 1]

data3 = pd.concat([data1, data2])
# 텍스트와 라벨 분리
data_contents = data3['text_remove_noun_morphed']
data_labeling = data3['aggr']

# 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(data_contents, data_labeling, stratify=data_labeling, test_size=0.2, random_state=42)

# 파이프라인 정의
pipelines = {

    'extra_trees': Pipeline([
        ('vect', TfidfVectorizer()),
        ('et', ExtraTreesClassifier())
    ]),

    'ridge_classifier': Pipeline([
        ('vect', TfidfVectorizer()),
        ('ridge', RidgeClassifier())
    ]),

    'logistic_regression': Pipeline([
        ('vect', TfidfVectorizer()),
        ('lr', LogisticRegression())
    ]),

    'naive_bayes': Pipeline([
        ('vect', TfidfVectorizer()),
        ('nb', MultinomialNB())
    ]),

    'svm': Pipeline([
        ('vect', TfidfVectorizer()),
        ('svm', SVC())
    ]),


    'hard_model' : Pipeline([
        ('vect', TfidfVectorizer()),
        ('hard_model',VotingClassifier([('LR',LogisticRegression()),('ridge',RidgeClassifier()),('svm',SVC()),('et',ExtraTreesClassifier()),('nb',MultinomialNB())],voting='hard'))

    ]),

    'soft_model' : Pipeline([
        ('vect', TfidfVectorizer()),
        ('soft_model',VotingClassifier([('LR',LogisticRegression()),('svm',SVC(probability=True)),('et',ExtraTreesClassifier()),('nb',MultinomialNB())],voting='soft'))

    ])
    

}

# 모델 훈련 및 평가
for model_name, pipeline in pipelines.items():
    print(f"Training {model_name}...")

    # 텍스트 데이터를 TF-IDF 벡터로 변환
    X_train_tfidf = pipeline.named_steps['vect'].fit_transform(X_train)
    X_test_tfidf = pipeline.named_steps['vect'].transform(X_test)
    
    # 차원 출력
    print(f"{model_name} - X_train shape: {X_train_tfidf.shape}")
    print(f"{model_name} - X_test shape: {X_test_tfidf.shape}")
    
    # 모델 훈련
    pipeline.fit(X_train, y_train)
    
    # 교차검증 점수 계산
    cv_scores = cross_val_score(pipeline, X_train, y_train, cv=5, scoring='accuracy')
    
    # 성능 출력
    train_score = pipeline.score(X_train, y_train)
    test_score = pipeline.score(X_test, y_test)
    print(f"{model_name} Train set score: {train_score:.4f}")
    print(f"{model_name} Test set score: {test_score:.4f}")
    print(f"{model_name} Cross-validation scores: {cv_scores}")
    print(f"{model_name} Cross-validation mean score: {cv_scores.mean():.4f}\n")
    
    # 모델 저장
    model_save_path = os.path.join('C:/Users/USER/Desktop/핵심역량 프로젝트/데이터/모델/', f'aggr_{model_name}_tfidf_nonemasking_model.pkl')
    joblib.dump(pipeline, model_save_path)

print("All models have been trained and saved.")
# Out:
# Training extra_trees...
# extra_trees - X_train shape: (585, 2620)
# extra_trees - X_test shape: (147, 2620)
# extra_trees Train set score: 0.9983
# extra_trees Test set score: 0.7483
# extra_trees Cross-validation scores: [0.75213675 0.74358974 0.73504274 0.7008547  0.73504274]
# extra_trees Cross-validation mean score: 0.7333
#
# Training ridge_classifier...
# ridge_classifier - X_train shape: (585, 2620)
# ridge_classifier - X_test shape: (147, 2620)
# ridge_classifier Train set score: 0.9846
# ridge_classifier Test set score: 0.8027
# ridge_classifier Cross-validation scores: [0.76923077 0.73504274 0.70940171 0.67521368 0.70940171]
# ridge_classifier Cross-validation mean score: 0.7197
#
# Training logistic_regression...
# logistic_regression - X_train shape: (585, 2620)
# logistic_regression - X_test shape: (147, 2620)
# logistic_regression Train set score: 0.9248
# logistic_regression Test set score: 0.7823
# logistic_regression Cross-validation scores: [0.74358974 0.70940171 0.73504274 0.73504274 0.70940171]
# logistic_regression Cross-validation mean score: 0.7265
#
# Training naive_bayes...
# naive_bayes - X_train shape: (585, 2620)
# naive_bayes - X_test shape: (147, 2620)
# naive_bayes Train set score: 0.9179
# naive_bayes Test set score: 0.7619
# naive_bayes Cross-validation scores: [0.72649573 0.73504274 0.69230769 0.64102564 0.65811966]
# naive_bayes Cross-validation mean score: 0.6906
#
# Training svm...
# svm - X_train shape: (585, 2620)
# svm - X_test shape: (147, 2620)
# svm Train set score: 0.9932
# svm Test set score: 0.7823
# svm Cross-validation scores: [0.75213675 0.74358974 0.72649573 0.7008547  0.7008547 ]
# svm Cross-validation mean score: 0.7248
#
# Training hard_model...
# hard_model - X_train shape: (585, 2620)
# hard_model - X_test shape: (147, 2620)
# hard_model Train set score: 0.9846
# hard_model Test set score: 0.7959
# hard_model Cross-validation scores: [0.75213675 0.73504274 0.71794872 0.70940171 0.70940171]
# hard_model Cross-validation mean score: 0.7248
#
# Training soft_model...
# soft_model - X_train shape: (585, 2620)
# soft_model - X_test shape: (147, 2620)
# soft_model Train set score: 0.9949
# soft_model Test set score: 0.8095
# soft_model Cross-validation scores: [0.75213675 0.75213675 0.72649573 0.71794872 0.70940171]
# soft_model Cross-validation mean score: 0.7316
#
# All models have been trained and saved.

# %% [markdown]
# ## TfidfVectorizer 마스킹 X, 파라미터 default - best 그리드 서치

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.ensemble import ExtraTreesClassifier, VotingClassifier
from sklearn.pipeline import Pipeline
import joblib

# 데이터 불러오기
os.chdir('C:/Users/USER/Desktop/핵심역량 프로젝트/데이터/라벨링 데이터')

data = pd.read_csv('0727_masking_labeling_data.csv')

selected_columns1 = ['text_morphed','title_morphed', 'aggr', '욕설_모욕', '비꼼_시비', '성희롱', '요지불명', '저격성 민원']
data1 = data[selected_columns1][data.aggr == 0]
data2 = data[selected_columns1][data.aggr == 1]
data1 = data1[300:812]
data2 = data2


data3 = pd.concat([data1, data2])
# 텍스트와 라벨 분리
data_contents = data3['text_morphed'] + ' ' + data3['title_morphed']
# 
# 원래의 'text_morphed_'와 'title' 컬럼 삭제
data_labeling = data3['aggr']

# 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(data_contents, data_labeling, stratify=data_labeling, test_size=0.2, random_state=42)

# 파이프라인 정의
pipelines = {
    'extra_trees': Pipeline([
        ('vect', TfidfVectorizer()),
        ('et', ExtraTreesClassifier())
    ]),
    'ridge_classifier': Pipeline([
        ('vect', TfidfVectorizer()),
        ('ridge', RidgeClassifier())
    ]),
    'logistic_regression': Pipeline([
        ('vect', TfidfVectorizer()),
        ('lr', LogisticRegression())
    ]),
    'naive_bayes': Pipeline([
        ('vect', TfidfVectorizer()),
        ('nb', MultinomialNB())
    ]),
    'svm': Pipeline([
        ('vect', TfidfVectorizer()),
        ('svm', SVC())
    ]),
    'hard_model' : Pipeline([
        ('vect', TfidfVectorizer()),
        ('hard_model',VotingClassifier([('LR',LogisticRegression()),('ridge',RidgeClassifier()),('svm',SVC()),('et',ExtraTreesClassifier()),('nb',MultinomialNB())],voting='hard'))

    ]),

    'soft_model' : Pipeline([
        ('vect', TfidfVectorizer()),
        ('soft_model',VotingClassifier([('LR',LogisticRegression()),('svm',SVC(probability=True)),('et',ExtraTreesClassifier()),('nb',MultinomialNB())],voting='soft'))
    ])
}

# 하이퍼파라미터 그리드 설정
param_grids = {
    'extra_trees': {
        'vect__ngram_range': [(1, 1), (1, 2)],
        'vect__max_df': [0.9, 1.0],
        'vect__min_df': [1, 2],
        'vect__max_features': [None, 1000],
        'et__n_estimators': [100],
        'et__max_features': ['auto', 'sqrt'],
        'et__max_depth': [None, 50],
    },
    'ridge_classifier': {
        'vect__ngram_range': [(1, 1), (1, 2)],
        'vect__max_df': [0.9, 1.0],
        'vect__min_df': [1, 2],
        'vect__max_features': [None, 1000],
        'ridge__alpha': [0.1, 1, 10],
    },
    'logistic_regression': {
        'vect__ngram_range': [(1, 1), (1, 2)],
        'vect__max_df': [0.9, 1.0],
        'vect__min_df': [1, 2],
        'vect__max_features': [None, 1000],
        'lr__C': [0.1, 1, 10],
        'lr__penalty': ['l1', 'l2'],
        'lr__solver': ['liblinear'],
    },
    'naive_bayes': {
        'vect__ngram_range': [(1, 1), (1, 2)],
        'vect__max_df': [0.9, 1.0],
        'vect__min_df': [1, 2],
        'vect__max_features': [None, 1000],
        'nb__alpha': [0.1, 1, 10],
    },
    'svm': {
        'vect__ngram_range': [(1, 1), (1, 2)],
        'vect__max_df': [0.9, 1.0],
        'vect__min_df': [1, 2],
        'vect__max_features': [None, 1000],
        'svm__C': [0.1, 1, 10],
        'svm__kernel': ['linear', 'rbf'],
        'svm__gamma': ['scale'],
    },
    'hard_model': {
        'vect__ngram_range': [(1, 1), (1, 2)],
        'vect__max_df': [0.9, 1.0],
        'vect__min_df': [1, 2],
        'vect__max_features': [None, 1000],
        'hard_model__LR__C': [0.1, 1],
        'hard_model__ridge__alpha': [0.1, 1],
        'hard_model__svm__C': [0.1, 1],
    },
    'soft_model': {
        'vect__ngram_range': [(1, 1), (1, 2)],
        'vect__max_df': [0.9, 1.0],
        'vect__min_df': [1, 2],
        'vect__max_features': [None, 1000],
        'soft_model__LR__C': [0.1, 1],
        'soft_model__svm__C': [0.1, 1],
        'soft_model__et__n_estimators': [100],
        'soft_model__nb__alpha': [0.1, 1],
    },
}

# 모델 훈련 및 평가
for model_name, pipeline in pipelines.items():
    print(f"Training {model_name}...")

    # 그리드 서치 설정
    param_grid = param_grids[model_name]
    grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
    
    # 그리드 서치 훈련
    grid_search.fit(X_train, y_train)
    
    # 최적 하이퍼파라미터 출력
    print(f"Best parameters for {model_name}: {grid_search.best_params_}")
    
    # 최적 모델 평가
    best_model = grid_search.best_estimator_
    train_score = best_model.score(X_train, y_train)
    test_score = best_model.score(X_test, y_test)
    
    # 교차 검증 점수 계산
    cv_scores = cross_val_score(best_model, X_train, y_train, cv=5, scoring='accuracy')
    
    # 성능 출력
    print(f"{model_name} Train set score: {train_score:.4f}")
    print(f"{model_name} Test set score: {test_score:.4f}")
    print(f"{model_name} Cross-validation scores: {cv_scores}")
    print(f"{model_name} Cross-validation mean score: {cv_scores.mean():.4f}\n")
    
    # 모델 저장
    model_save_path = os.path.join('C:/Users/USER/Desktop/핵심역량 프로젝트/데이터/모델/', f'aggr_{model_name}_tfidf_nonemasking_model.pkl')
    joblib.dump(best_model, model_save_path)

print("All models have been trained and saved.")
# Out:
# Training extra_trees...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 141
#     138 grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
#     140 # 그리드 서치 훈련
# --> 141 grid_search.fit(X_train, y_train)
#     143 # 최적 하이퍼파라미터 출력
#     144 print(f"Best parameters for {model_name}: {grid_search.best_params_}")
#
# File c:\Users\USER\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\USER\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
#    1387     """Search all candidates in param_grid"""
# -> 1388     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\USER\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File c:\Users\USER\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File c:\Users\USER\anaconda3\Lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File c:\Users\USER\anaconda3\Lib\threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:
